# %% [markdown]
# # Оператор связи «Ниединогоразрыва.ком»

# %% [markdown]
# **Описание**
#
# Оператор связи `«Ниединогоразрыва.ком»` хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия.

# %% [markdown]
# **Данные**
#
# Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах:
#
# - `contract_new.csv` — информация о договоре;
# - `personal_new.csv` — персональные данные клиента;
# - `internet_new.csv` — информация об интернет-услугах;
# - `phone_new.csv` — информация об услугах телефонии.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# **Цель**
#
# Обучить модель, которая будет прогнозировать отток клиентов, что со стороны заказчика поможет удерживать клиентскую базу и преумножить доход.

# %% [markdown]
# **Задачи**
#
# 1. Загрузка и изучение данных.
# * проверить соответствие типам данных
# * проверить наличие пропусков и дубликатов
# * проверить регистр столбцов
#
# 2. Подготовка данных
# * определить значащие признаки и составить целевой признак
# * соединить таблицы по полю `customerID`
#
# 3. Исследовательский анализ данных.
# * построить графики распределения данных
# * выявить аномальные значения в данных
#
# 5. Предобработка данных.
# * устранить пропуски и аномалии
# * исследовать признаки на мультиколлинеарность
# * выявить дисбаланс классов
#
# 6. Подготовка данных к обучению.
# * разделить данные на обучающую и тестовую выборки
# * закодировать данные и выполнить стандартизацию
#
# 7. Обучение модели.
# * подготовить и обучить модели, перебрав разные гиперпараметры
# * определить наилучшую модель
#
# 8. Проверка модели
# * протестирвать наилучшую модель на тестовой выборке
# * проанализировать матрицу ошибок
#
# 9. Анализ важности признаков.
#
# 10. Вывод.

# %% [markdown]
# ## Загрузка и изучение данных

# %% [markdown]
# Подключим необходимые библиотеки.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import phik

from sklearn.model_selection import (
    GridSearchCV,
    train_test_split
)

from sklearn.compose import make_column_transformer
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler
)
from sklearn.pipeline import Pipeline, make_pipeline

from sklearn.impute import SimpleImputer

from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import catboost as cb

from sklearn.metrics import confusion_matrix, \
    roc_auc_score, \
    accuracy_score



from sklearn.ensemble import RandomForestClassifier

RANDOM_STATE = 12

# %% [markdown]
#  Загрузим все предоставленные данные:
#
#  * data_contract — информация о договоре
#  * data_personal — персональные данные клиента
#  * data_internet — информация об интернет-услугах
#  * data_phone — информация об услугах телефонии
#
#  Информация о столбцах:
#
# * BeginDate – дата начала пользования услугами
# * EndDate – дата окончания пользования услугами
# * Type – тип оплаты: ежемесячный, годовой и тд
# * PaperlessBilling – электронный платёжный документ
# * PaymentMethod – способ оплаты
# * MonthlyCharges – ежемесячные траты на услуги по договору
# * TotalCharges – всего потрачено денег на услуги
# * Dependents – наличие иждивенцев
# * Senior Citizen – наличие пенсионного статуса по возрасту
# * Partner – наличие супруга(и)
# * MultipleLines – наличие возможности ведения параллельных линий во время звонка

# %%
try:
    data_contract = pd.read_csv('data/contract_new.csv')
    data_personal = pd.read_csv('data/personal_new.csv')
    data_internet = pd.read_csv('data/internet_new.csv')
    data_phone = pd.read_csv('data/phone_new.csv')
except Exception:
    data_contract = pd.read_csv('/datasets/contract_new.csv')
    data_personal = pd.read_csv('/datasets/personal_new.csv')
    data_internet = pd.read_csv('/datasets/internet_new.csv')
    data_phone = pd.read_csv('/datasets/phone_new.csv')

# %% [markdown]
# Выведем полученные таблицы, типы данных и общую информацию.

# %%
def display_data(data, name: str):
    print(f'Файл: {name}')
    display(data)
    print(f'\nТипы данных:\n\n{data.dtypes}',
          data.info(), 
          f'\n\nКоличеcтво дубликатов: {data.duplicated().sum()}\n')

# %%
tables = [data_contract, data_personal, data_internet, data_phone]
tables_name = ['Информация о договоре', 
               'Персональные данные клиента', 
              'Информация об интернет-услугах', 
              'информация об услугах телефонии']

for data, name in zip(tables, tables_name): 
    display_data(data, name)
    print('+---------------------------------------------------------+\n')
# Out:
# Файл: Информация о договоре
#       customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0     7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 1     5575-GNVDE  2017-04-01      No        One year               No
# 2     3668-QPYBK  2019-10-01      No  Month-to-month              Yes
# 3     7795-CFOCW  2016-05-01      No        One year               No
# 4     9237-HQITU  2019-09-01      No  Month-to-month              Yes
# ...          ...         ...     ...             ...              ...
# 7038  6840-RESVB  2018-02-01      No        One year              Yes
# 7039  2234-XADUH  2014-02-01      No        One year              Yes
# 7040  4801-JZAZL  2019-03-01      No  Month-to-month              Yes
# 7041  8361-LTMKD  2019-07-01      No  Month-to-month              Yes
# 7042  3186-AJIEK  2014-08-01      No        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges
# 0              Electronic check           29.85        31.04
# 1                  Mailed check           56.95      2071.84
# 2                  Mailed check           53.85       226.17
# 3     Bank transfer (automatic)           42.30       1960.6
# 4              Electronic check           70.70        353.5
# ...                         ...             ...          ...
# 7038               Mailed check           84.80       2035.2
# 7039    Credit card (automatic)          103.20       7430.4
# 7040           Electronic check           29.60        325.6
# 7041               Mailed check           74.40        520.8
# 7042  Bank transfer (automatic)          105.65      7251.82
#
# [7043 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
#
# Типы данных:
#
# customerID           object
# BeginDate            object
# EndDate              object
# Type                 object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# dtype: object None
#
# Количеcтво дубликатов: 0
#
# +---------------------------------------------------------+
#
# Файл: Персональные данные клиента
#       customerID  gender  SeniorCitizen Partner Dependents
# 0     7590-VHVEG  Female              0     Yes         No
# 1     5575-GNVDE    Male              0      No         No
# 2     3668-QPYBK    Male              0      No         No
# 3     7795-CFOCW    Male              0      No         No
# 4     9237-HQITU  Female              0      No         No
# ...          ...     ...            ...     ...        ...
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No
#
# [7043 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
#
# Типы данных:
#
# customerID       object
# gender           object
# SeniorCitizen     int64
# Partner          object
# Dependents       object
# dtype: object None
#
# Количеcтво дубликатов: 0
#
# +---------------------------------------------------------+
#
# Файл: Информация об интернет-услугах
#       customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0     7590-VHVEG             DSL             No          Yes               No
# 1     5575-GNVDE             DSL            Yes           No              Yes
# 2     3668-QPYBK             DSL            Yes          Yes               No
# 3     7795-CFOCW             DSL            Yes           No              Yes
# 4     9237-HQITU     Fiber optic             No           No               No
# ...          ...             ...            ...          ...              ...
# 5512  6840-RESVB             DSL            Yes           No              Yes
# 5513  2234-XADUH     Fiber optic             No          Yes              Yes
# 5514  4801-JZAZL             DSL            Yes           No               No
# 5515  8361-LTMKD     Fiber optic             No           No               No
# 5516  3186-AJIEK     Fiber optic            Yes           No              Yes
#
#      TechSupport StreamingTV StreamingMovies
# 0             No          No              No
# 1             No          No              No
# 2             No          No              No
# 3            Yes          No              No
# 4             No          No              No
# ...          ...         ...             ...
# 5512         Yes         Yes             Yes
# 5513          No         Yes             Yes
# 5514          No          No              No
# 5515          No          No              No
# 5516         Yes         Yes             Yes
#
# [5517 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
#
# Типы данных:
#
# customerID          object
# InternetService     object
# OnlineSecurity      object
# OnlineBackup        object
# DeviceProtection    object
# TechSupport         object
# StreamingTV         object
# StreamingMovies     object
# dtype: object None
#
# Количеcтво дубликатов: 0
#
# +---------------------------------------------------------+
#
# Файл: информация об услугах телефонии
#       customerID MultipleLines
# 0     5575-GNVDE            No
# 1     3668-QPYBK            No
# 2     9237-HQITU            No
# 3     9305-CDSKC           Yes
# 4     1452-KIOVK           Yes
# ...          ...           ...
# 6356  2569-WGERO            No
# 6357  6840-RESVB           Yes
# 6358  2234-XADUH           Yes
# 6359  8361-LTMKD           Yes
# 6360  3186-AJIEK            No
#
# [6361 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
#
# Типы данных:
#
# customerID       object
# MultipleLines    object
# dtype: object None
#
# Количеcтво дубликатов: 0
#
# +---------------------------------------------------------+

# %% [markdown]
# **Общий вывод:**
#
#
# * данные загружены корректно
# * столбцы необходимо привести к нижнему регистру, чтобы в будущем было удобнее обращаться к данным
# * дубликаты отсутсвуют
# * пропуски отсутсвуют
# * тип данных столбца `TotalCharges` таблицы `data_contract` необбходимо привести к типу `float`

# %% [markdown]
# Исправим найденные проблемы в данных.

# %% [markdown]
# Приведем все столбцы к нижнему регистру.

# %%
def low_col(column_el):
    return str.lower('_'.join(re.sub(r"([A-Z])", r" \1", column_el).split()))

# %%
data_contract.columns = map(low_col, data_contract.columns)
data_internet.columns = map(low_col, data_internet.columns)
data_phone.columns = map(low_col, data_phone.columns)
data_personal.columns = map(low_col, data_personal.columns)

# %% [markdown]
# При попытке изменения типа данных в столбце `totalcharges` были найдены неявные пропуски, а точнее пустые строки. Следовательно, необходимо заполнить эти пропуски значением Nan.

# %% [markdown]
# Теперь можем менять тип данных.

# %%
data_contract.total_charges = pd.to_numeric(data_contract.total_charges, errors = 'coerce')

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Соединим таблицы.

# %%
data_full = data_personal.merge(data_contract, how = 'left', on = 'customer_i_d')\
    .merge(data_internet, how = 'left', on = 'customer_i_d').\
    merge(data_phone, how = 'left', on = 'customer_i_d')

data_full
# Out:
#      customer_i_d  gender  senior_citizen partner dependents  begin_date  \
# 0      7590-VHVEG  Female               0     Yes         No  2020-01-01
# 1      5575-GNVDE    Male               0      No         No  2017-04-01
# 2      3668-QPYBK    Male               0      No         No  2019-10-01
# 3      7795-CFOCW    Male               0      No         No  2016-05-01
# 4      9237-HQITU  Female               0      No         No  2019-09-01
# ...           ...     ...             ...     ...        ...         ...
# 7038   6840-RESVB    Male               0     Yes        Yes  2018-02-01
# 7039   2234-XADUH  Female               0     Yes        Yes  2014-02-01
# 7040   4801-JZAZL  Female               0     Yes        Yes  2019-03-01
# 7041   8361-LTMKD    Male               1     Yes         No  2019-07-01
# 7042   3186-AJIEK    Male               0      No         No  2014-08-01
#
#      end_date            type paperless_billing             payment_method  \
# 0          No  Month-to-month               Yes           Electronic check
# 1          No        One year                No               Mailed check
# 2          No  Month-to-month               Yes               Mailed check
# 3          No        One year                No  Bank transfer (automatic)
# 4          No  Month-to-month               Yes           Electronic check
# ...       ...             ...               ...                        ...
# 7038       No        One year               Yes               Mailed check
# 7039       No        One year               Yes    Credit card (automatic)
# 7040       No  Month-to-month               Yes           Electronic check
# 7041       No  Month-to-month               Yes               Mailed check
# 7042       No        Two year               Yes  Bank transfer (automatic)
#
#       monthly_charges  total_charges internet_service online_security  \
# 0               29.85          31.04              DSL              No
# 1               56.95        2071.84              DSL             Yes
# 2               53.85         226.17              DSL             Yes
# 3               42.30        1960.60              DSL             Yes
# 4               70.70         353.50      Fiber optic              No
# ...               ...            ...              ...             ...
# 7038            84.80        2035.20              DSL             Yes
# 7039           103.20        7430.40      Fiber optic              No
# 7040            29.60         325.60              DSL             Yes
# 7041            74.40         520.80      Fiber optic              No
# 7042           105.65        7251.82      Fiber optic             Yes
#
#      online_backup device_protection tech_support streaming_t_v  \
# 0              Yes                No           No            No
# 1               No               Yes           No            No
# 2              Yes                No           No            No
# 3               No               Yes          Yes            No
# 4               No                No           No            No
# ...            ...               ...          ...           ...
# 7038            No               Yes          Yes           Yes
# 7039           Yes               Yes           No           Yes
# 7040            No                No           No            No
# 7041            No                No           No            No
# 7042            No               Yes          Yes           Yes
#
#      streaming_movies multiple_lines
# 0                  No            NaN
# 1                  No             No
# 2                  No             No
# 3                  No            NaN
# 4                  No             No
# ...               ...            ...
# 7038              Yes            Yes
# 7039              Yes            Yes
# 7040               No            NaN
# 7041               No            Yes
# 7042              Yes             No
#
# [7043 rows x 20 columns]

# %% [markdown]
# Создадим целевой признак, целевым признаком будем считать столбец `is_client`:
#
# * **1** - если в столбце присутствует дата
# * **0** - даты нет

# %%
data_full['end_date'] = data_full['end_date'].replace('No', '2020-02-01')

# %% [markdown]
# Создадим новый признак `duration_time_days` — срок пользования услугами в днях. В столбце `end_date` в значениях `No` поставим дату `2020-01-02`, так как это дата выгрузки данных.

# %%
data_full['is_client'] = data_full['end_date'].apply(lambda x: 1 if x != '2020-02-01' else 0)

# %% [markdown]
# Теперь создадим новый признак.

# %%
data_full[['end_date', 'begin_date']] = data_full[['end_date', 'begin_date']].astype("datetime64[ns]")
data_full['duration_time_days'] = (data_full.end_date - data_full.begin_date).dt.days

# %% [markdown]
# Выделим незначащие столбцы:
#
# * `customer_id` — id не будет давать существенного влияния при обучении.
# * `gender` — пол не будет давать существенного влияния при обучении.
# * `begindate` — дата заключения договора не будет давать существенного влияния при обучении.
# * `end_date` — дата заключения договора не будет давать существенного влияния при обучении.
#
# Удалим эти столбцы.

# %%
data_full = data_full.drop(['customer_i_d', 'gender', 'begin_date', 'end_date'], axis = 1)

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Построим распределение категориальных признаков.

# %%
cat_col = list(filter(lambda a: a not in ['monthly_charges',
                                          'total_charges',
                                          'duration_time_days'] , data_full.columns))

for i in range(0, len(cat_col)-1, 2):
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))
    ax[0].set_title(f'Distribution of {cat_col[i]}')
    ax[1].set_title(f'Distribution of {cat_col[i+1]}')

    sns.countplot(data = data_full, y = data_full[cat_col[i]], ax=ax[0])
    sns.countplot(data = data_full, y = data_full[cat_col[i+1]], ax=ax[1])

    ax[0].set_ylabel('')
    ax[1].set_ylabel('')
    fig.tight_layout()


    plt.show()
    print('+------------------------------------------------------------------------------------------------------------------------------------+\n')
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------------------------------------+
# +------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# Построим распределение численных признаков.

# %%
def hist_and_boxplot(data, column):
    fig, ax = plt.subplots(1, 2, figsize = (14, 7))
    sns.histplot(data[column], bins = 30, ax = ax[0])
    sns.boxplot(data[column], ax = ax[1])
    fig.suptitle(f'Distribution of {column}', size = 12)
    plt.show()


print(data_full[['monthly_charges', 'total_charges', 'duration_time_days']].describe())
for column in ['monthly_charges',
               'total_charges',
               'duration_time_days']:
    hist_and_boxplot(data_full, column)
# Out:
#        monthly_charges  total_charges  duration_time_days
# count      7043.000000    7032.000000         7043.000000
# mean         64.761692    2118.621822          898.555729
# std          30.090047    2112.736199          683.130510
# min          18.250000      19.050000            0.000000
# 25%          35.500000     439.745000          276.000000
# 50%          70.350000    1345.275000          761.000000
# 75%          89.850000    3239.317500         1461.000000
# max         118.750000    9221.380000         2314.000000

# %% [markdown]
# **Вывод:**
#
# Категориальные признаки:
#
# * аномальные значения отсутствуют
# * `senior_citizen` — преобладает отсутствие пенсионного статуса по возрасту
# * `dependents` — преобладает отсутствие иждивенца
# * `end_date` — преобладают пользователи, которые не покинули сервис
# * `type` — преобладает тип подписки `Month-to-Month`
# * `online_security` — преобладает отсутствие онлайн защиты
#
# Численные признаки:
#
# * аномальные значения отсутствуют
# * присутствуют сильные пики у значения `0`

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Выведем количество пропусков в процентном соотношении.

# %%
def plot_null():
    null_values = round(data_full.isna().sum().sort_values(ascending = False) / data_full.shape[0], 4)
    sns.barplot(y = null_values.index, x = null_values.values)
    print(null_values)

# %%
plot_null()
# Out:
# online_security       0.2167
# online_backup         0.2167
# streaming_movies      0.2167
# streaming_t_v         0.2167
# tech_support          0.2167
# internet_service      0.2167
# device_protection     0.2167
# multiple_lines        0.0968
# total_charges         0.0016
# is_client             0.0000
# senior_citizen        0.0000
# partner               0.0000
# monthly_charges       0.0000
# payment_method        0.0000
# paperless_billing     0.0000
# type                  0.0000
# dependents            0.0000
# duration_time_days    0.0000
# dtype: float64

# %% [markdown]
# Видно, что в данных из таблицы `data_phone` (информация об услугах телефонии) присутствует много пропусков. Следовательно, либо данные некоторых клиентов не внесены в базу, либо у клиента попросту нет данных функций. Так как процент данных слишком велик, возможности удалить данные нет, поэтому заполним пропуски отрицательными значениями. Пропуски в значениях столбца `multiple_lines` можем заполнить по тому же принципу.
#
#
# Пропусков в значениях столбца `total_charges` говорят о том, что пользователь еще не усаел совершить покупки, поэтому заполним значением 0.

# %%
data_full.iloc[ : , 8:17 ] = data_full.iloc[ : , 8:17 ].fillna('No')
data_full.fillna(0, inplace=True)

# %% [markdown]
# Проверим оставшиеся пропуски.

# %%
plot_null()
# Out:
# senior_citizen        0.0
# partner               0.0
# is_client             0.0
# multiple_lines        0.0
# streaming_movies      0.0
# streaming_t_v         0.0
# tech_support          0.0
# device_protection     0.0
# online_backup         0.0
# online_security       0.0
# internet_service      0.0
# total_charges         0.0
# monthly_charges       0.0
# payment_method        0.0
# paperless_billing     0.0
# type                  0.0
# dependents            0.0
# duration_time_days    0.0
# dtype: float64

# %% [markdown]
# Пропусков больше нет!

# %% [markdown]
# Необходимо проверить неявные пропуски, но из пункта `Исследовательский анализ данных` можно сделать вывод, что они отсутствуют.

# %% [markdown]
# Исследуем признаки на мультиколлинеарность.

# %%
interval_columns = ['monthly_charges',
                    'total_charges',
                    'duration_time_days']

corr = data_full.phik_matrix(interval_cols = interval_columns)
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(color='#f1f1f1')
 .format(precision=2))
# Out:
# <style type="text/css">
# #T_decc3_row0_col0, #T_decc3_row0_col1, #T_decc3_row0_col2, #T_decc3_row0_col3, #T_decc3_row0_col4, #T_decc3_row0_col5, #T_decc3_row0_col6, #T_decc3_row0_col7, #T_decc3_row0_col8, #T_decc3_row0_col9, #T_decc3_row0_col10, #T_decc3_row0_col11, #T_decc3_row0_col12, #T_decc3_row0_col13, #T_decc3_row0_col14, #T_decc3_row0_col15, #T_decc3_row0_col16, #T_decc3_row0_col17, #T_decc3_row1_col1, #T_decc3_row1_col2, #T_decc3_row1_col3, #T_decc3_row1_col4, #T_decc3_row1_col5, #T_decc3_row1_col6, #T_decc3_row1_col7, #T_decc3_row1_col8, #T_decc3_row1_col9, #T_decc3_row1_col10, #T_decc3_row1_col11, #T_decc3_row1_col12, #T_decc3_row1_col13, #T_decc3_row1_col14, #T_decc3_row1_col15, #T_decc3_row1_col16, #T_decc3_row1_col17, #T_decc3_row2_col2, #T_decc3_row2_col3, #T_decc3_row2_col4, #T_decc3_row2_col5, #T_decc3_row2_col6, #T_decc3_row2_col7, #T_decc3_row2_col8, #T_decc3_row2_col9, #T_decc3_row2_col10, #T_decc3_row2_col11, #T_decc3_row2_col12, #T_decc3_row2_col13, #T_decc3_row2_col14, #T_decc3_row2_col15, #T_decc3_row2_col16, #T_decc3_row2_col17, #T_decc3_row3_col3, #T_decc3_row3_col4, #T_decc3_row3_col5, #T_decc3_row3_col6, #T_decc3_row3_col7, #T_decc3_row3_col8, #T_decc3_row3_col9, #T_decc3_row3_col10, #T_decc3_row3_col11, #T_decc3_row3_col12, #T_decc3_row3_col13, #T_decc3_row3_col14, #T_decc3_row3_col15, #T_decc3_row3_col16, #T_decc3_row3_col17, #T_decc3_row4_col4, #T_decc3_row4_col5, #T_decc3_row4_col6, #T_decc3_row4_col7, #T_decc3_row4_col8, #T_decc3_row4_col9, #T_decc3_row4_col10, #T_decc3_row4_col11, #T_decc3_row4_col12, #T_decc3_row4_col13, #T_decc3_row4_col14, #T_decc3_row4_col15, #T_decc3_row4_col16, #T_decc3_row4_col17, #T_decc3_row5_col5, #T_decc3_row5_col6, #T_decc3_row5_col7, #T_decc3_row5_col8, #T_decc3_row5_col9, #T_decc3_row5_col10, #T_decc3_row5_col11, #T_decc3_row5_col12, #T_decc3_row5_col13, #T_decc3_row5_col14, #T_decc3_row5_col15, #T_decc3_row5_col16, #T_decc3_row5_col17, #T_decc3_row6_col6, #T_decc3_row6_col7, #T_decc3_row6_col8, #T_decc3_row6_col9, #T_decc3_row6_col10, #T_decc3_row6_col11, #T_decc3_row6_col12, #T_decc3_row6_col13, #T_decc3_row6_col14, #T_decc3_row6_col15, #T_decc3_row6_col16, #T_decc3_row6_col17, #T_decc3_row7_col7, #T_decc3_row7_col8, #T_decc3_row7_col9, #T_decc3_row7_col10, #T_decc3_row7_col11, #T_decc3_row7_col12, #T_decc3_row7_col13, #T_decc3_row7_col14, #T_decc3_row7_col15, #T_decc3_row7_col16, #T_decc3_row7_col17, #T_decc3_row8_col8, #T_decc3_row8_col9, #T_decc3_row8_col10, #T_decc3_row8_col11, #T_decc3_row8_col12, #T_decc3_row8_col13, #T_decc3_row8_col14, #T_decc3_row8_col15, #T_decc3_row8_col16, #T_decc3_row8_col17, #T_decc3_row9_col9, #T_decc3_row9_col10, #T_decc3_row9_col11, #T_decc3_row9_col12, #T_decc3_row9_col13, #T_decc3_row9_col14, #T_decc3_row9_col15, #T_decc3_row9_col16, #T_decc3_row9_col17, #T_decc3_row10_col10, #T_decc3_row10_col11, #T_decc3_row10_col12, #T_decc3_row10_col13, #T_decc3_row10_col14, #T_decc3_row10_col15, #T_decc3_row10_col16, #T_decc3_row10_col17, #T_decc3_row11_col11, #T_decc3_row11_col12, #T_decc3_row11_col13, #T_decc3_row11_col14, #T_decc3_row11_col15, #T_decc3_row11_col16, #T_decc3_row11_col17, #T_decc3_row12_col12, #T_decc3_row12_col13, #T_decc3_row12_col14, #T_decc3_row12_col15, #T_decc3_row12_col16, #T_decc3_row12_col17, #T_decc3_row13_col13, #T_decc3_row13_col14, #T_decc3_row13_col15, #T_decc3_row13_col16, #T_decc3_row13_col17, #T_decc3_row14_col14, #T_decc3_row14_col15, #T_decc3_row14_col16, #T_decc3_row14_col17, #T_decc3_row15_col15, #T_decc3_row15_col16, #T_decc3_row15_col17, #T_decc3_row16_col16, #T_decc3_row16_col17, #T_decc3_row17_col17 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_decc3_row1_col0, #T_decc3_row13_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_decc3_row2_col0, #T_decc3_row8_col5, #T_decc3_row14_col4 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_decc3_row2_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_decc3_row3_col0, #T_decc3_row11_col0, #T_decc3_row12_col0, #T_decc3_row16_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_decc3_row3_col1, #T_decc3_row6_col2, #T_decc3_row12_col1, #T_decc3_row12_col3, #T_decc3_row14_col0, #T_decc3_row14_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_decc3_row3_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_decc3_row4_col0, #T_decc3_row9_col8, #T_decc3_row11_col1, #T_decc3_row12_col8 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_decc3_row4_col1, #T_decc3_row11_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_decc3_row4_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_decc3_row4_col3, #T_decc3_row8_col2, #T_decc3_row10_col0, #T_decc3_row16_col12 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_decc3_row5_col0, #T_decc3_row14_col9 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_decc3_row5_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_decc3_row5_col2, #T_decc3_row9_col1, #T_decc3_row10_col1, #T_decc3_row15_col0, #T_decc3_row15_col1, #T_decc3_row15_col8, #T_decc3_row16_col6, #T_decc3_row16_col14 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_decc3_row5_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_decc3_row5_col4, #T_decc3_row17_col16 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_decc3_row6_col0, #T_decc3_row11_col5, #T_decc3_row15_col10, #T_decc3_row15_col11 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_decc3_row6_col1 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_decc3_row6_col3, #T_decc3_row17_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_decc3_row6_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_decc3_row6_col5, #T_decc3_row17_col12 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_decc3_row7_col0, #T_decc3_row11_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_decc3_row7_col1, #T_decc3_row13_col5, #T_decc3_row14_col5 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_decc3_row7_col2, #T_decc3_row16_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_decc3_row7_col3 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_decc3_row7_col4, #T_decc3_row10_col4, #T_decc3_row16_col13, #T_decc3_row17_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_decc3_row7_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_decc3_row7_col6 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_decc3_row8_col0, #T_decc3_row11_col4, #T_decc3_row13_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_decc3_row8_col1, #T_decc3_row9_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_decc3_row8_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_decc3_row8_col4, #T_decc3_row10_col8, #T_decc3_row11_col8, #T_decc3_row16_col1, #T_decc3_row16_col10 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_decc3_row8_col6 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_decc3_row8_col7 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_decc3_row9_col0, #T_decc3_row12_col4, #T_decc3_row14_col2, #T_decc3_row16_col8, #T_decc3_row17_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_decc3_row9_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_decc3_row9_col3, #T_decc3_row15_col9, #T_decc3_row15_col12 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_decc3_row9_col5, #T_decc3_row16_col15 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_decc3_row9_col6, #T_decc3_row12_col7 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_decc3_row9_col7 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_decc3_row10_col2, #T_decc3_row15_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_decc3_row10_col3, #T_decc3_row12_col2, #T_decc3_row16_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_decc3_row10_col5 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_decc3_row10_col6 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_decc3_row10_col7 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_decc3_row10_col9 {
#   background-colo

# %% [markdown]
# Возьмем пороговое значение корреляции — `0.8`. Тогда можно сделать вывод, что:

# %% [markdown]
# * столбцы `internet_service`,  `streaming_t_v`, `streaming_movies` сильно коррелируют с признаком `monthly_charges`, поэтому их необходимо удалить
# * столбец `total_charges` сильно коррелирует со столбцом `duration_time_days`, поэтому удалим столбец `total_charges`

# %%
data_full = data_full.drop(['internet_service',  'streaming_t_v', 'streaming_movies', 'total_charges'], axis = 1)

# %% [markdown]
# Проверим целевой признак на дисбаланс классов.

# %%
plt.pie(data_full.is_client.value_counts(), labels = ['0', '1'], autopct='%1.0f%%')

my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Distribution target')

plt.show()

# %% [markdown]
# Дисбаланс классов присутствует.

# %% [markdown]
# **Вывод:**
#
# * устранены пропуски и аномалии
# * проведено исследование признаков на мултколлениарность, что позволило избавиться от лишних столбцов
# * выявлен дисбаланс классов, поэтому будем использовать метрику качества `AUC-ROC`, которая нечувствительна к дисбалансу

# %% [markdown]
# ## Подготовка данных к обучению.

# %% [markdown]
# Разделим данные на обучающую и тестовую выборки.

# %%
features = data_full.drop(['is_client'], axis=1)
target = data_full['is_client']

features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.20, random_state=RANDOM_STATE, stratify=target
)

# %% [markdown]
# Начнем кодирование данных. Кодирование будем выполнять с помощью OrdinalEncoder.

# %%
features_train.senior_citizen = features_train.senior_citizen.astype('object')

ohe_features = features_train.select_dtypes(include='object').columns.to_list()
num_features = features_train.select_dtypes(exclude='object').columns.to_list()

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Обучим разные модели.
#
# Простые модели:
#
# * DecisionTreeClassifier
# * RandomForestClassifier
#
# Модели на основе градиентного бустинга:
#
# * CatBoostClassifier

# %% [markdown]
# Подготовим пайплайн для обучения моделей.

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features),  # количественные признаки
        ('cat', OneHotEncoder(), ohe_features)  # категориальные признаки
    ])

pipeline = Pipeline([
    ('scaler', preprocessor),
    ('model', None)
]
)


param_grid = [
    {
        'model': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear')],
        'model__C': np.logspace(-3,3,20),
        'model__penalty': ["l1", "l2"]
    },
    {
        'model': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'model__criterion': ['gini','entropy'],
        'model__max_depth': range(1, 6)
    },
    {
        'model': [RandomForestClassifier(random_state=RANDOM_STATE)],
        'model__n_estimators': range(10, 101, 30),
        'model__max_depth': range(1, 6)
    },
    {
        'model': [cb.CatBoostClassifier(random_state=RANDOM_STATE)],
        'model__learning_rate': [0.01, 0.03, 0.001],
        'model__depth': range(1, 6)
    }
]

# %% [markdown]
# Создадим модели, и подберем параметры с помощью GridSearchCV.

# %%
def get_results(model, name):
    print(f''
          f'Модель {name}:\n' \
           f'Параметры: {model.best_params_}\n' \
           f'ROC-AUC: {model.best_score_}')

# %%
interaction_only=True

# %%
grid_pipe = GridSearchCV(pipeline,
                         param_grid,
                         cv = 3,
                         scoring='roc_auc',
                         error_score='raise',
                         verbose=0)
grid_pipe.fit(features_train, target_train)
# Out:
# 0:	learn: 0.6872306	total: 638us	remaining: 638ms
# 1:	learn: 0.6813785	total: 1.18ms	remaining: 588ms
# 2:	learn: 0.6757311	total: 1.65ms	remaining: 548ms
# 3:	learn: 0.6701772	total: 2.12ms	remaining: 528ms
# 4:	learn: 0.6648169	total: 2.59ms	remaining: 515ms
# 5:	learn: 0.6594715	total: 3.05ms	remaining: 506ms
# 6:	learn: 0.6545184	total: 3.54ms	remaining: 502ms
# 7:	learn: 0.6494813	total: 4.01ms	remaining: 497ms
# 8:	learn: 0.6447855	total: 4.48ms	remaining: 493ms
# 9:	learn: 0.6397999	total: 4.95ms	remaining: 490ms
# 10:	learn: 0.6350941	total: 5.41ms	remaining: 486ms
# 11:	learn: 0.6299652	total: 5.88ms	remaining: 484ms
# 12:	learn: 0.6250390	total: 6.34ms	remaining: 481ms
# 13:	learn: 0.6206021	total: 6.79ms	remaining: 478ms
# 14:	learn: 0.6161472	total: 7.28ms	remaining: 478ms
# 15:	learn: 0.6117972	total: 7.78ms	remaining: 478ms
# 16:	learn: 0.6076759	total: 8.23ms	remaining: 476ms
# 17:	learn: 0.6037743	total: 8.69ms	remaining: 474ms
# 18:	learn: 0.5997989	total: 9.19ms	remaining: 474ms
# 19:	learn: 0.5958625	total: 9.66ms	remaining: 473ms
# 20:	learn: 0.5919711	total: 10.1ms	remaining: 472ms
# 21:	learn: 0.5882109	total: 10.6ms	remaining: 470ms
# 22:	learn: 0.5846140	total: 11.1ms	remaining: 469ms
# 23:	learn: 0.5813068	total: 11.5ms	remaining: 469ms
# 24:	learn: 0.5780284	total: 12ms	remaining: 468ms
# 25:	learn: 0.5746297	total: 12.5ms	remaining: 466ms
# 26:	learn: 0.5710118	total: 12.9ms	remaining: 465ms
# 27:	learn: 0.5677746	total: 13.4ms	remaining: 464ms
# 28:	learn: 0.5645156	total: 13.9ms	remaining: 464ms
# 29:	learn: 0.5608264	total: 14.5ms	remaining: 468ms
# 30:	learn: 0.5577953	total: 14.9ms	remaining: 467ms
# 31:	learn: 0.5549469	total: 15.4ms	remaining: 467ms
# 32:	learn: 0.5519997	total: 15.9ms	remaining: 466ms
# 33:	learn: 0.5491947	total: 16.4ms	remaining: 466ms
# 34:	learn: 0.5463353	total: 16.9ms	remaining: 465ms
# 35:	learn: 0.5436149	total: 17.3ms	remaining: 464ms
# 36:	learn: 0.5408833	total: 17.8ms	remaining: 463ms
# 37:	learn: 0.5383249	total: 18.3ms	remaining: 462ms
# 38:	learn: 0.5357150	total: 18.7ms	remaining: 461ms
# 39:	learn: 0.5332399	total: 19.2ms	remaining: 462ms
# 40:	learn: 0.5308649	total: 19.8ms	remaining: 462ms
# 41:	learn: 0.5284229	total: 20.2ms	remaining: 462ms
# 42:	learn: 0.5260241	total: 20.7ms	remaining: 461ms
# 43:	learn: 0.5236815	total: 21.2ms	remaining: 460ms
# 44:	learn: 0.5213960	total: 21.7ms	remaining: 461ms
# 45:	learn: 0.5191896	total: 22.3ms	remaining: 462ms
# 46:	learn: 0.5172601	total: 22.8ms	remaining: 462ms
# 47:	learn: 0.5147457	total: 23.4ms	remaining: 463ms
# 48:	learn: 0.5121879	total: 23.9ms	remaining: 463ms
# 49:	learn: 0.5101968	total: 24.4ms	remaining: 463ms
# 50:	learn: 0.5082513	total: 24.9ms	remaining: 463ms
# 51:	learn: 0.5060059	total: 25.3ms	remaining: 462ms
# 52:	learn: 0.5040870	total: 25.8ms	remaining: 461ms
# 53:	learn: 0.5022128	total: 26.3ms	remaining: 460ms
# 54:	learn: 0.5003299	total: 26.8ms	remaining: 461ms
# 55:	learn: 0.4981461	total: 27.4ms	remaining: 463ms
# 56:	learn: 0.4964606	total: 27.9ms	remaining: 462ms
# 57:	learn: 0.4948191	total: 28.4ms	remaining: 461ms
# 58:	learn: 0.4931339	total: 28.9ms	remaining: 461ms
# 59:	learn: 0.4914611	total: 29.5ms	remaining: 462ms
# 60:	learn: 0.4898495	total: 30ms	remaining: 462ms
# 61:	learn: 0.4878220	total: 30.6ms	remaining: 464ms
# 62:	learn: 0.4864768	total: 31.2ms	remaining: 464ms
# 63:	learn: 0.4850377	total: 31.7ms	remaining: 464ms
# 64:	learn: 0.4833885	total: 32.2ms	remaining: 463ms
# 65:	learn: 0.4815871	total: 32.8ms	remaining: 464ms
# 66:	learn: 0.4800110	total: 33.3ms	remaining: 464ms
# 67:	learn: 0.4786176	total: 33.9ms	remaining: 464ms
# 68:	learn: 0.4774687	total: 34.4ms	remaining: 464ms
# 69:	learn: 0.4760771	total: 35ms	remaining: 464ms
# 70:	learn: 0.4748381	total: 35.5ms	remaining: 465ms
# 71:	learn: 0.4735271	total: 36ms	remaining: 464ms
# 72:	learn: 0.4723133	total: 36.5ms	remaining: 464ms
# 73:	learn: 0.4708444	total: 37.1ms	remaining: 464ms
# 74:	learn: 0.4696858	total: 37.6ms	remaining: 464ms
# 75:	learn: 0.4681429	total: 38.3ms	remaining: 465ms
# 76:	learn: 0.4670652	total: 38.7ms	remaining: 464ms
# 77:	learn: 0.4659473	total: 39.2ms	remaining: 463ms
# 78:	learn: 0.4648831	total: 39.7ms	remaining: 463ms
# 79:	learn: 0.4633999	total: 40.2ms	remaining: 462ms
# 80:	learn: 0.4619796	total: 40.7ms	remaining: 461ms
# 81:	learn: 0.4609015	total: 41.1ms	remaining: 461ms
# 82:	learn: 0.4598877	total: 41.7ms	remaining: 460ms
# 83:	learn: 0.4588808	total: 42.2ms	remaining: 460ms
# 84:	learn: 0.4580896	total: 42.7ms	remaining: 460ms
# 85:	learn: 0.4571698	total: 43.2ms	remaining: 459ms
# 86:	learn: 0.4562705	total: 43.7ms	remaining: 458ms
# 87:	learn: 0.4552853	total: 44.2ms	remaining: 458ms
# 88:	learn: 0.4542505	total: 44.7ms	remaining: 458ms
# 89:	learn: 0.4534081	total: 45.2ms	remaining: 457ms
# 90:	learn: 0.4525328	total: 45.7ms	remaining: 457ms
# 91:	learn: 0.4516588	total: 46.2ms	remaining: 456ms
# 92:	learn: 0.4508094	total: 46.7ms	remaining: 455ms
# 93:	learn: 0.4500690	total: 47.2ms	remaining: 455ms
# 94:	learn: 0.4489789	total: 47.8ms	remaining: 456ms
# 95:	learn: 0.4481543	total: 48.4ms	remaining: 455ms
# 96:	learn: 0.4470145	total: 49ms	remaining: 456ms
# 97:	learn: 0.4459970	total: 49.5ms	remaining: 456ms
# 98:	learn: 0.4452466	total: 50ms	remaining: 455ms
# 99:	learn: 0.4445028	total: 50.5ms	remaining: 454ms
# 100:	learn: 0.4438274	total: 51ms	remaining: 454ms
# 101:	learn: 0.4428325	total: 51.7ms	remaining: 455ms
# 102:	learn: 0.4421308	total: 52.2ms	remaining: 454ms
# 103:	learn: 0.4412780	total: 52.8ms	remaining: 454ms
# 104:	learn: 0.4405707	total: 53.2ms	remaining: 454ms
# 105:	learn: 0.4398795	total: 53.7ms	remaining: 453ms
# 106:	learn: 0.4389373	total: 54.2ms	remaining: 453ms
# 107:	learn: 0.4382710	total: 54.7ms	remaining: 452ms
# 108:	learn: 0.4376200	total: 55.2ms	remaining: 451ms
# 109:	learn: 0.4370040	total: 55.7ms	remaining: 450ms
# 110:	learn: 0.4364025	total: 56.2ms	remaining: 450ms
# 111:	learn: 0.4358077	total: 56.8ms	remaining: 450ms
# 112:	learn: 0.4352298	total: 57.3ms	remaining: 450ms
# 113:	learn: 0.4346355	total: 57.8ms	remaining: 449ms
# 114:	learn: 0.4338018	total: 58.5ms	remaining: 450ms
# 115:	learn: 0.4332287	total: 59ms	remaining: 450ms
# 116:	learn: 0.4326686	total: 59.5ms	remaining: 449ms
# 117:	learn: 0.4321780	total: 60ms	remaining: 448ms
# 118:	learn: 0.4313907	total: 60.6ms	remaining: 449ms
# 119:	learn: 0.4308723	total: 61.1ms	remaining: 448ms
# 120:	learn: 0.4304089	total: 61.6ms	remaining: 447ms
# 121:	learn: 0.4297364	total: 62.1ms	remaining: 447ms
# 122:	learn: 0.4292479	total: 62.6ms	remaining: 446ms
# 123:	learn: 0.4287704	total: 63.1ms	remaining: 446ms
# 124:	learn: 0.4283012	total: 63.6ms	remaining: 445ms
# 125:	learn: 0.4275430	total: 64.2ms	remaining: 445ms
# 126:	learn: 0.4268409	total: 64.8ms	remaining: 445ms
# 127:	learn: 0.4264322	total: 65.3ms	remaining: 445ms
# 128:	learn: 0.4260026	total: 65.8ms	remaining: 444ms
# 129:	learn: 0.4256092	total: 66.4ms	remaining: 444ms
# 130:	learn: 0.4251855	total: 66.8ms	remaining: 443ms
# 131:	learn: 0.4247670	total: 67.3ms	remaining: 443ms
# 132:	learn: 0.4243671	total: 67.8ms	remaining: 442ms
# 133:	learn: 0.4240540	total: 68.3ms	remaining: 442ms
# 134:	learn: 0.4235610	total: 68.9ms	remaining: 441ms
# 135:	learn: 0.4231426	total: 69.4ms	remaining: 441ms
# 136:	learn: 0.4228217	total: 69.8ms	remaining: 440ms
# 137:	learn: 0.4223262	total: 70.3ms	remaining: 439ms
# 138:	learn: 0.4219835	total: 70.8ms	remaining: 439ms
# 139:	learn: 0.4216569	total: 71.4ms	remaining: 438ms
# 140:	learn: 0.4212955	total: 71.9ms	remaining: 438ms
# 141:	learn: 0.4206575	total: 72.5ms	remaining: 438ms
# 142:	learn: 0.4203082	total: 72.9ms	remaining: 437ms
# 143:	learn: 0.4199669	total: 73.4ms	remaining: 436ms
# 144:	learn: 0.4196623	total: 73.9ms	remaining: 436ms
# 145:	learn: 0.4193626	total: 74.4ms	remaining: 435ms
# 146:	learn: 0.4190057	total: 74.8ms	remaining: 434ms
# 147:	learn: 0.4186861	total: 75.3ms	remaining: 434ms
# 148:	learn: 0.4184024	total: 75.9ms	remaining: 433ms
# 149:	learn: 0.4179962	total: 76.4ms	remaining: 433ms
# 150:	learn: 0.4176861	total: 76.9ms	remaining: 432ms
# 151:	learn: 0.4173834	total: 77.4ms	remaining: 432ms
# 152:	learn: 0.4171275	total: 77.9ms	remaining: 431ms
# 153:	learn: 0.4168652	total: 78.4ms	remaining: 431ms
# 154:	learn: 0.4163177	total: 79ms	remaining: 430ms
# 155:	learn: 0.4160336	total: 79.4ms	remaining: 430ms
# 156:	learn: 0.4155438	total: 79.9ms	remaining: 429ms
# 157:	learn: 0.4150668	total: 80.6ms	remaining: 430ms
# 158:	learn: 0.4148235	total: 81.2ms	remaining: 429ms
# 159:	learn: 0.4145167	total: 81.7ms	remaining: 429ms
# 160:	learn: 0.4140142	total: 82.2ms	remaining: 428ms
# 161:	learn: 0.4135275	total: 82.8ms	remaining: 428ms
# 162:	learn: 0.4132962	total: 83.3ms	remaining: 428ms
# 163:	learn: 0.4128219	total: 83.9ms	remaining: 428ms
# 164:	learn: 0.4124578	total: 84.4ms	remaining: 427ms
# 165:	learn: 0.4121695	total: 84.8ms	remaining: 426ms
# 166:	learn: 0.4117291	total: 85.3ms	remaining: 426ms
# 167:	learn: 0.4114483	total: 85.7ms	remaining: 425ms
# 168:	learn: 0.4111736	total: 86.2ms	remaining: 424ms
# 169:	learn: 0.4109311	total: 86.6ms	remaining: 423ms
# 170:	learn: 0.4107072	total: 87.1ms	remaining: 422ms
# 171:	learn: 0.4104993	total: 87.5ms	remaining: 421ms
# 172:	learn: 0.4102682	total: 88ms	remaining: 420ms
# 173:	learn: 0.4098463	total: 88.5ms	remaining: 420ms
# 174:	learn: 0.4095873	total: 88.9ms	remaining: 419ms
# 175:	learn: 0.4091621	total: 89.5ms	remaining: 419ms
# 176:	learn: 0.4089097	total: 89.9ms	remaining: 418ms
# 177:	learn: 0.4087174	total: 90.4ms	remaining: 418ms
# 178:	learn: 0.4085423	total: 91ms	remaining: 417ms
# 179:	learn: 0.4081925	total: 91.5ms	remaining: 417ms
# 180:	learn: 0.4078242	total: 92ms	remaining: 416ms
# 181:	learn: 0.4075410	total: 92.6ms	remaining: 416ms
# 182:	learn: 0.4073628	total: 93.1ms	remaining: 415ms
# 183:	learn: 0.4071562	total: 93.6ms	remaining: 415ms
# 184:	learn: 0.4069538	total: 94.1ms	remaining: 414ms
# 185:	learn: 0.4067860	total: 94.6ms	remaining: 414ms
# 186:	learn: 0.4065880	total: 95ms	remaining: 413ms
# 187:	learn: 0.4063655	total: 95.5ms	remaining: 412ms
# 188:	learn: 0.4062042	total: 95.9ms	remaining: 412ms
# 189:	learn: 0.4059877	total: 96.4ms	remaining: 411ms
# 190:	learn: 0.4057983	total: 96.9ms	remaining: 411ms
# 191:	learn: 0.4056129	total: 97.4ms	remaining: 410ms
# 192:	learn: 0.4052077	total: 98ms	remaining: 410ms
# 193:	learn: 0.4047985	total: 98.5ms	remaining: 409ms
# 194:	learn: 0.4046162	total: 99ms	remaining: 409ms
# 195:	learn: 0.4044381	total: 99.5ms	remaining: 408ms
# 196:	learn: 0.4042325	total: 100ms	remaining: 408ms
# 197:	learn: 0.4040786	total: 100ms	remaining: 407ms
# 198:	learn: 0.4037771	total: 101ms	remaining: 407ms
# 199:	learn: 0.4036061	total: 102ms	remaining: 406ms
# 200:	learn: 0.4034750	total: 102ms	remaining: 406ms
# 201:	learn: 0.4031193	total: 103ms	remaining: 405ms
# 202:	learn: 0.4029807	total: 103ms	remaining: 405ms
# 203:	learn: 0.4027840	total: 104ms	remaining: 404ms
# 204:	learn: 0.4025918	total: 104ms	remaining: 404ms
# 205:	learn: 0.4024274	total: 105ms	remaining: 403ms
# 206:	learn: 0.4022890	total: 105ms	remaining: 402ms
# 207:	learn: 0.4019292	total: 106ms	remaining: 402ms
# 208:	learn: 0.4017917	total: 106ms	remaining: 401ms
# 209:	learn: 0.4016065	total: 107ms	remaining: 401ms
# 210:	learn: 0.4013379	total: 107ms	remaining: 400ms
# 211:	learn: 0.4010361	total: 108ms	remaining: 400ms
# 212:	learn: 0.4007200	total: 108ms	remaining: 399ms
# 213:	learn: 0.4005849	total: 109ms	remaining: 399ms
# 214:	learn: 0.4003182	total: 109ms	remaining: 398ms
# 215:	learn: 0.4001168	total: 110ms	remaining: 398ms
# 216:	learn: 0.3998264	total: 110ms	remaining: 398ms
# 217:	learn: 0.3997488	total: 111ms	remaining: 397ms
# 218:	learn: 0.3996093	total: 111ms	remaining: 397ms
# 219:	learn: 0.3994879	total: 112ms	remaining: 396ms
# 220:	learn: 0.3993136	total: 112ms	remaining: 395ms
# 221:	learn: 0.3990095	total: 113ms	remaining: 395ms
# 222:	learn: 0.3988635	total: 113ms	remaining: 395ms
# 223:	learn: 0.3986469	total: 114ms	remaining: 394ms
# 224:	learn: 0.3985052	total: 114ms	remaining: 394ms
# 225:	learn: 0.3983377	total: 115ms	remaining: 393ms
# 226:	learn: 0.3982002	total: 115ms	remaining: 393ms
# 227:	learn: 0.3980598	total: 116ms	remaining: 392ms
# 228:	learn: 0.3978974	total: 116ms	remaining: 391ms
# 229:	learn: 0.3977336	total: 117ms	remaining: 391ms
# 230:	learn: 0.3976245	total: 117ms	remaining: 390ms
# 231:	learn: 0.3974686	total: 118ms	remaining: 389ms
# 232:	learn: 0.3973357	total: 118ms	remaining: 389ms
# 233:	learn: 0.3972072	total: 119ms	remaining: 388ms
# 234:	learn: 0.3971076	total: 119ms	remaining: 388ms
# 235:	learn: 0.3969569	total: 120ms	remaining: 387ms
# 236:	learn: 0.3967790	total: 120ms	remaining: 386ms
# 237:	learn: 0.3966336	total: 120ms	remaining: 386ms
# 238:	learn: 0.3964909	total: 121ms	remaining: 385ms
# 239:	learn: 0.3962113	total: 121ms	remaining: 385ms
# 240:	learn: 0.3960867	total: 122ms	remaining: 384ms
# 241:	learn: 0.3959650	total: 122ms	remaining: 383ms
# 242:	learn: 0.3958846	total: 123ms	remaining: 383ms
# 243:	learn: 0.3957801	total: 123ms	remaining: 382ms
# 244:	learn: 0.3956629	total: 124ms	remaining: 381ms
# 245:	learn: 0.3953435	total: 124ms	remaining: 381ms
# 246:	learn: 0.3951270	total: 125ms	remaining: 380ms
# 247:	learn: 0.3948883	total: 125ms	remaining: 380ms
# 248:	learn: 0.3947500	total: 126ms	remaining: 379ms
# 249:	learn: 0.3946299	total: 126ms	remaining: 378ms
# 250:	learn: 0.3943796	total: 127ms	remaining: 378ms
# 251:	learn: 0.3942437	total: 127ms	remaining: 377ms
# 252:	learn: 0.3941482	total: 127ms	remaining: 376ms
# 253:	learn: 0.3940567	total: 128ms	remaining: 376ms
# 254:	learn: 0.3939504	total: 128ms	remaining: 375ms
# 255:	learn: 0.3937925	total: 129ms	remaining: 375ms
# 256:	learn: 0.3935139	total: 130ms	remaining: 375ms
# 257:	learn: 0.3932533	total: 130ms	remaining: 374ms
# 258:	learn: 0.3930266	total: 131ms	remaining: 374ms
# 259:	learn: 0.3929380	total: 131ms	remaining: 373ms
# 260:	learn: 0.3928053	total: 132ms	remaining: 372ms
# 261:	learn: 0.3925458	total: 132ms	remaining: 372ms
# 262:	learn: 0.3924358	total: 132ms	remaining: 371ms
# 263:	learn: 0.3921602	total: 133ms	remaining: 371ms
# 264:	learn: 0.3919084	total: 134ms	remaining: 371ms
# 265:	learn: 0.3917114	total: 134ms	remaining: 370ms
# 266:	learn: 0.3916486	total: 135ms	remaining: 370ms
# 267:	learn: 0.3915538	total: 135ms	remaining: 369ms
# 268:	learn: 0.3914615	total: 136ms	remaining: 368ms
# 269:	learn: 0.3911143	total: 136ms	remaining: 368ms
# 270:	learn: 0.3910225	total: 137ms	remaining: 368ms
# 271:	learn: 0.3909261	total: 137ms	remaining: 367ms
# 272:	learn: 0.3908129	total: 138ms	remaining: 367ms
# 273:	learn: 0.3907262	total: 138ms	remaining: 366ms
# 274:	learn: 0.3905946	total: 139ms	remaining: 366ms
# 275:	learn: 0.3904925	total: 139ms	remaining: 365ms
# 276:	learn: 0.3904114	total: 140ms	remaining: 365ms
# 277:	learn: 0.3902275	total: 140ms	remaining: 364ms
# 278:	learn: 0.3901196	total: 141ms	remaining: 363ms
# 279:	learn: 0.3899018	total: 141ms	remaining: 363ms
# 280:	learn: 0.3896781	total: 142ms	remaining: 363ms
# 281:	learn: 0.3895501	total: 142ms	remaining: 362ms
# 282:	learn: 0.3893711	total: 143ms	remaining: 362ms
# 283:	learn: 0.3892726	total: 143ms	remaining: 361ms
# 284:	learn: 0.3891787	total: 144ms	remaining: 361ms
# 285:	learn: 0.3890827	total: 144ms	remaining: 360ms
# 286:	learn: 0.3889786	total: 145ms	remaining: 359ms
# 287:	learn: 0.3888763	total: 145ms	remaining: 359ms
# 288:	learn: 0.3886496	total: 146ms	remaining: 358ms
# 289:	learn: 0.3885732	total: 146ms	remaining: 358ms
# 290:	learn: 0.3884026	total: 147ms	remaining: 357ms
# 291:	learn: 0.3883091	total: 147ms	remaining: 357ms
# 292:	learn: 0.3881848	total: 148ms	remaining: 356ms
# 293:	learn: 0.3880634	total: 148ms	remaining: 356ms
# 294:	learn: 0.3879894	total: 149ms	remaining: 355ms
# 295:	learn: 0.3878905	total: 149ms	remaining: 354ms
# 296:	learn: 0.3877935	total: 149ms	remaining: 354ms
# 297:	learn: 0.3877134	total: 150ms	remaining: 353ms
# 298:	learn: 0.3876247	total: 150ms	remaining: 352ms
# 299:	learn: 0.3875301	total: 151ms	remaining: 352ms
# 300:	learn: 0.3873891	total: 151ms	remaining: 351ms
# 301:	learn: 0.3872717	total: 152ms	remaining: 351ms
# 302:	learn: 0.3870530	total: 152ms	remaining: 350ms
# 303:	learn: 0.3869598	total: 153ms	remaining: 350ms
# 304:	learn: 0.3868546	total: 153ms	remaining: 349ms
# 305:	learn: 0.3867739	total: 154ms	remaining: 349ms
# 306:	learn: 0.3866095	total: 154ms	remaining: 348ms
# 307:	learn: 0.3865299	total: 155ms	remaining: 348ms
# 308:	learn: 0.3864146	total: 155ms	remaining: 347ms
# 309:	learn: 0.3863016	total: 156ms	remaining: 347ms
# 310:	learn: 0.3861909	total: 156ms	remaining: 346ms
# 311:	learn: 0.3861049	total: 157ms	remaining: 346ms
# 312:	learn: 0.3860174	total: 157ms	remaining: 345ms
# 313:	learn: 0.3859543	total: 158ms	remaining: 345ms
# 314:	learn: 0.3858855	total: 158ms	remaining: 344ms
# 315:	learn: 0.3857213	total: 159ms	remaining: 343ms
# 316:	learn: 0.3855850	total: 159ms	remaining: 343ms
# 317:	learn: 0.3855201	total: 160ms	remaining: 342ms
# 318:	learn: 0.3854538	total: 160ms	remaining: 342ms
# 319:	learn: 0.3853801	total: 161ms	remaining: 341ms
# 320:	learn: 0.3852483	total: 161ms	remaining: 341ms
# 321:	learn: 0.3850411	total: 162ms	remaining: 340ms
# 322:	learn: 0.3848846	total: 162ms	remaining: 340ms
# 323:	learn: 0.3847980	total: 163ms	remaining: 339ms
# 324:	learn: 0.3847293	total: 163ms	remaining: 339ms
# 325:	learn: 0.3845363	total: 164ms	remaining: 338ms
# 326:	learn: 0.3844514	total: 164ms	remaining: 338ms
# 327:	learn: 0.3843449	total: 165ms	remaining: 337ms
# 328:	learn: 0.3842723	total: 165ms	remaining: 337ms
# 329:	learn: 0.3842086	total: 166ms	remaining: 336ms
# 330:	learn: 0.3841470	total: 166ms	remaining: 336ms
# 331:	learn: 0.3840429	total: 167ms	remaining: 335ms
# 332:	learn: 0.3839408	total: 167ms	remaining: 335ms
# 333:	learn: 0.3838411	total: 168ms	remaining: 334ms
# 334:	learn: 0.3837430	total: 168ms	remaining: 334ms
# 335:	learn: 0.3836473	total: 169ms	remaining: 333ms
# 336:	learn: 0.3835785	total: 169ms	remaining: 333ms
# 337:	learn: 0.3834984	total: 170ms	remaining: 332ms
# 338:	learn: 0.3834182	total: 170ms	remaining: 332ms
# 339:	learn: 0.3833403	total: 171ms	remaining: 331ms
# 340:	learn: 0.3832611	total: 171ms	remaining: 331ms
# 341:	learn: 0.3831684	total: 171ms	remaining: 330ms
# 342:	learn: 0.3829904	total: 172ms	remaining: 329ms
# 343:	learn: 0.3827814	total: 173ms	remaining: 329ms
# 344:	learn: 0.3826884	total: 173ms	remaining: 329ms
# 345:	learn: 0.3826291	total: 174ms	remaining: 328ms
# 346:	learn: 0.3824123	total: 174ms	remaining: 328ms
# 347:	learn: 0.3823200	total: 175ms	remaining: 327ms
# 348:	learn: 0.3822622	total: 175ms	remaining: 327ms
# 349:	learn: 0.3820404	total: 176ms	remaining: 326ms
# 350:	learn: 0.3819622	total: 176ms	remaining: 326ms
# 351:	learn: 0.3818852	total: 177ms	remaining: 325ms
# 352:	learn: 0.3818288	total: 177ms	remaining: 325ms
# 353:	learn: 0.3817383	total: 178ms	remaining: 324ms
# 354:	learn: 0.3816634	total: 178ms	remaining: 324ms
# 355:	learn: 0.3814894	total: 179ms	remaining: 323ms
# 356:	learn: 0.3812964	total: 179ms	remaining: 323ms
# 357:	learn: 0.3812345	total: 180ms	remaining: 322ms
# 358:	learn: 0.3811443	total: 180ms	remaining: 322ms
# 359:	learn: 0.3810703	total: 181ms	remaining: 321ms
# 360:	learn: 0.3810079	total: 181ms	remaining: 320ms
# 361:	learn: 0.3809328	total: 181ms	remaining: 320ms
# 362:	learn: 0.3808603	total: 182ms	remaining: 319ms
# 363:	learn: 0.3806730	total: 183ms	remaining: 319ms
# 364:	learn: 0.3805985	total: 183ms	remaining: 318ms
# 365:	learn: 0.3804221	total: 183ms	remaining: 318ms
# 366:	learn: 0.3803556	total: 184ms	remaining: 317ms
# 367:	learn: 0.3802659	total: 185ms	remaining: 317ms
# 368:	learn: 0.3801929	total: 185ms	remaining: 316ms
# 369:	learn: 0.3801212	total: 185ms	remaining: 316ms
# 370:	learn: 0.3799176	total: 186ms	remaining: 315ms
# 371:	learn: 0.3798462	total: 186ms	remaining: 315ms
# 372:	learn: 0.3797904	total: 187ms	remaining: 314ms
# 373:	learn: 0.3797206	total: 187ms	remaining: 314ms
# 374:	learn: 0.3796331	total: 188ms	remaining: 313ms
# 375:	learn: 0.3794793	total: 189ms	remaining: 313ms
# 376:	learn: 0.3793749	total: 189ms	remaining: 312ms
# 377:	learn: 0.3793219	total: 190ms	remaining: 312ms
# 378:	learn: 0.3791419	total: 190ms	remaining: 311ms
# 379:	learn: 0.3790738	total: 191ms	remaining: 311ms
# 380:	learn: 0.3790246	total: 191ms	remaining: 311ms
# 381:	learn: 0.3789577	total: 192ms	remaining: 311ms
# 382:	learn: 0.3787838	total: 193ms	remaining: 310ms
# 383:	learn: 0.3786966	total: 193ms	remaining: 310ms
# 384:	learn: 0.3786211	total: 194ms	remaining: 309ms
# 385:	learn: 0.3785557	total: 194ms	remaining: 309ms
# 386:	learn: 0.3784706	total: 195ms	remaining: 308ms
# 387:	learn: 0.3784069	total: 195ms	remaining: 308ms
# 388:	learn: 0.3782354	total: 196ms	remaining: 307ms
# 389:	learn: 0.3780478	total: 196ms	remaining: 307ms
# 390:	learn: 0.3779775	total: 197ms	remaining: 307ms
# 391:	learn: 0.3779133	total: 197ms	remaining: 306ms
# 392:	learn: 0.3778287	total: 198ms	remaining: 306ms
# 393:	learn: 0.3777549	total: 198ms	remaining: 305ms
# 394:	learn: 0.3776915	total: 199ms	remaining: 305ms
# 395:	learn: 0.3776408	total: 199ms	remaining: 304ms
# 396:	learn: 0.3775586	total: 200ms	remaining: 304ms
# 397:	learn: 0.3774781	total: 201ms	remaining: 303ms
# 398:	learn: 0.3774103	total: 201ms	remaining: 303ms
# 399:	learn: 0.3773488	total: 202ms	remaining: 303ms
# 400:	learn: 0.3771269	total: 202ms	remaining: 302ms
# 401:	learn: 0.3770272	total: 203ms	remaining: 302ms
# 402:	learn: 0.3769472	total: 203ms	remaining: 301ms
# 403:	learn: 0.3767658	total: 204ms	remaining: 301ms
# 404:	learn: 0.3766976	total: 204ms	remaining: 300ms
# 405:	learn: 0.3766180	total: 205ms	remaining: 300ms
# 406:	learn: 0.3765560	total: 206ms	remaining: 300ms
# 407:	learn: 0.3764836	total: 206ms	remaining: 299ms
# 408:	learn: 0.3764178	total: 207ms	remaining: 299ms
# 409:	learn: 0.3763568	total: 207ms	remaining: 298ms
# 410:	learn: 0.3762364	total: 208ms	remaining: 298ms
# 411:	learn: 0.3761004	total: 208ms	remaining: 297ms
# 412:	learn: 0.3759847	total: 209ms	remaining: 297ms
# 413:	learn: 0.3759240	total: 209ms	remaining: 296ms
# 414:	learn: 0.3758642	total: 210ms	remaining: 296ms
# 415:	learn: 0.3757094	total: 210ms	remaining: 295ms
# 416:	learn: 0.3756308	total: 211ms	remaining: 295ms
# 417:	learn: 0.3755535	total: 211ms	remaining: 294ms
# 418:	learn: 0.3754343	total: 212ms	remaining: 294ms
# 419:	learn: 0.3753756	total: 212ms	remaining: 293ms
# 420:	learn: 0.3752853	total: 213ms	remaining: 293ms
# 421:	learn: 0.3752201	total: 213ms	remaining: 292ms
# 422:	learn: 0.3751626	total: 214ms	remaining: 292ms
# 423:	learn: 0.3750987	total: 214ms	remaining: 291ms
# 424:	learn: 0.3750366	total: 215ms	remaining: 291ms
# 425:	learn: 0.3749887	total: 215ms	remaining: 290ms
# 426:	learn: 0.3749282	total: 216ms	remaining: 290ms
# 427:	learn: 0.3748188	total: 216ms	remaining: 289ms
# 428:	learn: 0.3747492	total: 217ms	remaining: 289ms
# 429:	learn: 0.3746895	total: 217ms	remaining: 288ms
# 430:	learn: 0.3746124	total: 218ms	remaining: 288ms
# 431:	learn: 0.3745626	total: 218ms	remaining: 287ms
# 432:	learn: 0.3745078	total: 219ms	remaining: 287ms
# 433:	learn: 0.3744604	total: 219ms	remaining: 286ms
# 434:	learn: 0.3744069	total: 220ms	remaining: 286ms
# 435:	learn: 0.3743451	total: 220ms	remaining: 285ms
# 436:	learn: 0.3742883	total: 221ms	remaining: 285ms
# 437:	learn: 0.3742348	total: 222ms	remaining: 284ms
# 438:	learn: 0.3740651	total: 222ms	remaining: 284ms
# 439:	learn: 0.3739889	total: 223ms	remaining: 283ms
# 440:	learn: 0.3739441	total: 223ms	remaining: 283ms
# 441:	learn: 0.3738830	total: 224ms	remaining: 283ms
# 442:	learn: 0.3738231	total: 224ms	remaining: 282ms
# 443:	learn: 0.3737648	total: 225ms	remaining: 282ms
# 444:	learn: 0.3736842	total: 225ms	remaining: 281ms
# 445:	learn: 0.3736261	total: 226ms	remaining: 281ms
# 446:	learn: 0.3735601	total: 227ms	remaining: 280ms
# 447:	learn: 0.3734938	total: 227ms	remaining: 280ms
# 448:	learn: 0.3734466	total: 227ms	remaining: 279ms
# 449:	learn: 0.3733929	total: 228ms	remaining: 279ms
# 450:	learn: 0.3733352	total: 229ms	remaining: 278ms
# 451:	learn: 0.3732826	total: 229ms	remaining: 278ms
# 452:	learn: 0.3732105	total: 230ms	remaining: 277ms
# 453:	learn: 0.3731680	total: 230ms	remaining: 277ms
# 454:	learn: 0.3731156	total: 231ms	remaining: 276ms
# 455:	learn: 0.3730682	total: 231ms	remaining: 276ms
# 456:	learn: 0.3730126	total: 232ms	remaining: 275ms
# 457:	learn: 0.3728232	total: 232ms	remaining: 275ms
# 458:	learn: 0.3727674	total: 233ms	remaining: 274ms
# 459:	learn: 0.3727126	total: 233ms	remaining: 274ms
# 460:	learn: 0.3726773	total: 234ms	remaining: 274ms
# 461:	learn: 0.3725912	total: 235ms	remaining: 273ms
# 462:	learn: 0.3725372	total: 235ms	remaining: 273ms
# 463:	learn: 0.3724108	total: 236ms	remaining: 272ms
# 464:	learn: 0.3723595	total: 236ms	remaining: 272ms
# 465:	learn: 0.3723136	total: 236ms	remaining: 271ms
# 466:	learn: 0.3722435	total: 237ms	remaining: 270ms
# 467:	learn: 0.3721926	total: 237ms	remaining: 270ms
# 468:	learn: 0.3721035	total: 238ms	remaining: 269ms
# 469:	learn: 0.3719377	total: 238ms	remaining: 269ms
# 470:	learn: 0.3718159	total: 239ms	remaining: 268ms
# 471:	learn: 0.3717462	total: 239ms	remaining: 268ms
# 472:	learn: 0.3716779	total: 240ms	remaining: 267ms
# 473:	learn: 0.3716114	total: 240ms	remaining: 267ms
# 474:	learn: 0.3714523	total: 241ms	remaining: 266ms
# 475:	learn: 0.3713340	total: 241ms	remaining: 266ms
# 476:	learn: 0.3712667	total: 242ms	remaining: 265ms
# 477:	learn: 0.3712026	total: 242ms	remaining: 265ms
# 478:	learn: 0.3711372	total: 243ms	remaining: 264ms
# 479:	learn: 0.3710863	total: 243ms	remaining: 264ms
# 480:	learn: 0.3709694	total: 244ms	remaining: 263ms
# 481:	learn: 0.3709192	total: 244ms	remaining: 263ms
# 482:	learn: 0.3708634	total: 245ms	remaining: 262ms
# 483:	learn: 0.3708006	total: 245ms	remaining: 262ms
# 484:	learn: 0.3707515	total: 246ms	remaining: 261ms
# 485:	learn: 0.3706243	total: 247ms	remaining: 261ms
# 486:	learn: 0.3705164	total: 247ms	remaining: 260ms
# 487:	learn: 0.3704681	total: 248ms	remaining: 260ms
# 488:	learn: 0.3704131	total: 248ms	remaining: 259ms
# 489:	learn: 0.3703591	total: 249ms	remaining: 259ms
# 490:	learn: 0.3702655	total: 249ms	remaining: 258ms
# 491:	learn: 0.3702008	total: 250ms	remaining: 258ms
# 492:	learn: 0.3701489	total: 250ms	remaining: 257ms
# 493:	learn: 0.3700857	total: 251ms	remaining: 257ms
# 494:	learn: 0.3700064	total: 251ms	remaining: 256ms
# 495:	learn: 0.3698580	total: 252ms	remaining: 256ms
# 496:	learn: 0.3697402	total: 253ms	remaining: 256ms
# 497:	learn: 0.3696902	total: 253ms	remaining: 255ms
# 498:	learn: 0.3696424	total: 254ms	remaining: 255ms
# 499:	learn: 0.3695908	total: 254ms	remaining: 254ms
# 500:	learn: 0.3695448	total: 255ms	remaining: 254ms
# 501:	learn: 0.3694940	total: 255ms	remaining: 253ms
# 502:	learn: 0.3694451	total: 256ms	remaining: 253ms
# 503:	learn: 0.3694093	total: 256ms	remaining: 252ms
# 504:	learn: 0.3693726	total: 257ms	remaining: 252ms
# 505:	learn: 0.3693093	total: 257ms	remaining: 251ms
# 506:	learn: 0.3692633	total: 258ms	remaining: 251ms
# 507:	learn: 0.3692030	total: 258ms	remaining: 250ms
# 508:	learn: 0.3691486	total: 259ms	remaining: 250ms
# 509:	learn: 0.3690896	total: 259ms	remaining: 249ms
# 510:	learn: 0.3690408	total: 260ms	remaining: 249ms
# 511:	learn: 0.3689964	total: 260ms	remaining: 248ms
# 512:	learn: 0.3689486	total: 261ms	remaining: 248ms
# 513:	learn: 0.3689051	total: 262ms	remaining: 247ms
# 514:	learn: 0.3688087	total: 262ms	remaining: 247ms
# 515:	learn: 0.3687663	total: 262ms	remaining: 246ms
# 516:	learn: 0.3687202	total: 263ms	remaining: 246ms
# 517:	learn: 0.3686102	total: 263ms	remaining: 245ms
# 518:	learn: 0.3685778	total: 264ms	remaining: 245ms
# 519:	learn: 0.3685377	total: 264ms	remaining: 244ms
# 520:	learn: 0.3684847	total: 265ms	remaining: 244ms
# 521:	learn: 0.3684250	total: 266ms	remaining: 243ms
# 522:	learn: 0.3683834	total: 266ms	remaining: 243ms
# 523:	learn: 0.3682441	total: 267ms	remaining: 242ms
# 524:	learn: 0.3681875	total: 267ms	remaining: 242ms
# 525:	learn: 0.3681561	total: 268ms	remaining: 241ms
# 526:	learn: 0.3680969	total: 268ms	remaining: 241ms
# 527:	learn: 0.3680390	total: 269ms	remaining: 240ms
# 528:	learn: 0.3679943	total: 269ms	remaining: 240ms
# 529:	learn: 0.3679387	total: 270ms	remaining: 239ms
# 530:	learn: 0.3678933	total: 270ms	remaining: 239ms
# 531:	learn: 0.3678595	total: 271ms	remaining: 238ms
# 532:	learn: 0.3678158	total: 271ms	remaining: 238ms
# 533:	learn: 0.3677992	total: 272ms	remaining: 237ms
# 534:	learn: 0.3677627	total: 272ms	remaining: 237ms
# 535:	learn: 0.3677187	total: 273ms	remaining: 236ms
# 536:	learn: 0.3676762	total: 274ms	remaining: 236ms
# 537:	learn: 0.3676198	total: 274ms	remaining: 235ms
# 538:	learn: 0.3675393	total: 275ms	remaining: 235ms
# 539:	learn: 0.3674840	total: 275ms	remaining: 234ms
# 540:	learn: 0.3674449	total: 276ms	remaining: 234ms
# 541:	learn: 0.3674145	total: 276ms	remaining: 233ms
# 542:	learn: 0.3673614	total: 277ms	remaining: 233ms
# 543:	learn: 0.3673072	total: 277ms	remaining: 232ms
# 544:	learn: 0.3671779	total: 278ms	remaining: 232ms
# 545:	learn: 0.3670343	total: 279ms	remaining: 232ms
# 546:	learn: 0.3669800	total: 279ms	remaining: 231ms
# 547:	learn: 0.3668722	total: 280ms	remaining: 231ms
# 548:	learn: 0.3667782	total: 280ms	remaining: 230ms
# 549:	learn: 0.3666470	total: 281ms	remaining: 230ms
# 550:	learn: 0.3665965	total: 281ms	remaining: 229ms
# 551:	learn: 0.3665672	total: 282ms	remaining: 229ms
# 552:	learn: 0.3665384	total: 282ms	remaining: 228ms
# 553:	learn: 0.3664995	total: 283ms	remaining: 228ms
# 554:	learn: 0.3664474	total: 283ms	remaining: 227ms
# 555:	learn: 0.3663940	total: 284ms	remaining: 227ms
# 556:	learn: 0.3663034	total: 284ms	remaining: 226ms
# 557:	learn: 0.3662685	total: 285ms	remaining: 226ms
# 558:	learn: 0.3662163	total: 285ms	remaining: 225ms
# 559:	learn: 0.3661571	total: 286ms	remaining: 225ms
# 560:	learn: 0.3661293	total: 286ms	remaining: 224ms
# 561:	learn: 0.3660864	total: 287ms	remaining: 223ms
# 562:	learn: 0.3660381	total: 287ms	remaining: 223ms
# 563:	learn: 0.3659904	total: 288ms	remaining: 222ms
# 564:	learn: 0.3658707	total: 288ms	remaining: 222ms
# 565:	learn: 0.3658231	total: 289ms	remaining: 221ms
# 566:	learn: 0.3657722	total: 289ms	remaining: 221ms
# 567:	learn: 0.3657346	total: 290ms	remaining: 220ms
# 568:	learn: 0.3657011	total: 290ms	remaining: 220ms
# 569:	learn: 0.3655808	total: 291ms	remaining: 219ms
# 570:	learn: 0.3655478	total: 291ms	remaining: 219ms
# 571:	learn: 0.3654467	total: 292ms	remaining: 218ms
# 572:	learn: 0.3654097	total: 292ms	remaining: 218ms
# 573:	learn: 0.3653625	total: 293ms	remaining: 217ms
# 574:	learn: 0.3653162	total: 294ms	remaining: 217ms
# 575:	learn: 0.3652458	total: 294ms	remaining: 216ms
# 576:	learn: 0.3652116	total: 295ms	remaining: 216ms
# 577:	learn: 0.3651709	total: 295ms	remaining: 215ms
# 578:	learn: 0.3650883	total: 296ms	remaining: 215ms
# 579:	learn: 0.3650465	total: 296ms	remaining: 214ms
# 580:	learn: 0.3649890	total: 297ms	remaining: 214ms
# 581:	learn: 0.3649517	total: 297ms	remaining: 214ms
# 582:	learn: 0.3649022	total: 298ms	remaining: 213ms
# 583:	learn: 0.3648538	total: 298ms	remaining: 213ms
# 584:	learn: 0.3648132	total: 299ms	remaining: 212ms
# 585:	learn: 0.3647822	total: 299ms	remaining: 212ms
# 586:	learn: 0.3647347	total: 300ms	remaining: 211ms
# 587:	learn: 0.3646183	total: 300ms	remaining: 211ms
# 588:	learn: 0.3645690	total: 301ms	remaining: 210ms
# 589:	learn: 0.3645070	total: 302ms	remaining: 210ms
# 590:	learn: 0.3644015	total: 302ms	remaining: 209ms
# 591:	learn: 0.3643560	total: 303ms	remaining: 209ms
# 592:	learn: 0.3643093	total: 303ms	remaining: 208ms
# 593:	learn: 0.3642601	total: 304ms	remaining: 207ms
# 594:	learn: 0.3641340	total: 304ms	remaining: 207ms
# 595:	learn: 0.3640872	total: 305ms	remaining: 206ms
# 596:	learn: 0.3639702	total: 305ms	remaining: 206ms
# 597:	learn: 0.3639210	total: 306ms	remaining: 205ms
# 598:	learn: 0.3638898	total: 306ms	remaining: 205ms
# 599:	learn: 0.3638473	total: 307ms	remaining: 204ms
# 600:	learn: 0.3638117	total: 307ms	remaining: 204ms
# 601:	learn: 0.3637652	total: 308ms	remaining: 203ms
# 602:	learn: 0.3637172	total: 308ms	remaining: 203ms
# 603:	learn: 0.3636003	total: 309ms	remaining: 202ms
# 604:	learn: 0.3635539	total: 309ms	remaining: 202ms
# 605:	learn: 0.3635091	total: 310ms	remaining: 201ms
# 606:	learn: 0.3634643	total: 310ms	remaining: 201ms
# 607:	learn: 0.3634350	total: 311ms	remaining: 200ms
# 608:	learn: 0.3633286	total: 311ms	remaining: 200ms
# 609:	learn: 0.3632902	total: 312ms	remaining: 199ms
# 610:	learn: 0.3632456	total: 312ms	remaining: 199ms
# 611:	learn: 0.3632059	total: 312ms	remaining: 198ms
# 612:	learn: 0.3630807	total: 313ms	remaining: 198ms
# 613:	learn: 0.3630415	total: 313ms	remaining: 197ms
# 614:	learn: 0.3629968	total: 314ms	remaining: 197ms
# 615:	learn: 0.3629536	total: 315ms	remaining: 196ms
# 616:	learn: 0.3628727	total: 315ms	remaining: 196ms
# 617:	learn: 0.3628300	total: 316ms	remaining: 195ms
# 618:	learn: 0.3628006	total: 316ms	remaining: 195ms
# 619:	learn: 0.3627618	total: 317ms	remaining: 194ms
# 620:	learn: 0.3627057	total: 317ms	remaining: 194ms
# 621:	learn: 0.3626637	total: 318ms	remaining: 193ms
# 622:	learn: 0.3626229	total: 318ms	remaining: 193ms
# 623:	learn: 0.3625823	total: 319ms	remaining: 192ms
# 624:	learn: 0.3625586	total: 319ms	remaining: 192ms
# 625:	learn: 0.3625211	total: 320ms	remaining: 191ms
# 626:	learn: 0.3624814	total: 320ms	remaining: 190ms
# 627:	learn: 0.3623604	total: 321ms	remaining: 190ms
# 628:	learn: 0.3622433	total: 321ms	remaining: 189ms
# 629:	learn: 0.3622094	total: 322ms	remaining: 189ms
# 630:	learn: 0.3621624	total: 322ms	remaining: 188ms
# 631:	learn: 0.3621281	total: 323ms	remaining: 188ms
# 632:	learn: 0.3621016	total: 323ms	remaining: 187ms
# 633:	learn: 0.3620647	total: 324ms	remaining: 187ms
# 634:	learn: 0.3620366	total: 324ms	remaining: 186ms
# 635:	learn: 0.3619487	total: 325ms	remaining: 186ms
# 636:	learn: 0.3619031	total: 325ms	remaining: 185ms
# 637:	learn: 0.3618667	total: 326ms	remaining: 185ms
# 638:	learn: 0.3618310	total: 326ms	remaining: 184ms
# 639:	learn: 0.3617907	total: 327ms	remaining: 184ms
# 640:	learn: 0.3617558	total: 327ms	remaining: 183ms
# 641:	learn: 0.3617117	total: 328ms	remaining: 183ms
# 642:	learn: 0.3616528	total: 328ms	remaining: 182ms
# 643:	learn: 0.3616130	total: 329ms	remaining: 182ms
# 644:	learn: 0.3615764	total: 329ms	remaining: 181ms
# 645:	learn: 0.3614381	total: 330ms	remaining: 181ms
# 646:	learn: 0.3614081	total: 330ms	remaining: 180ms
# 647:	learn: 0.3613649	total: 331ms	remaining: 180ms
# 648:	learn: 0.3613310	total: 331ms	remaining: 179ms
# 649:	learn: 0.3612910	total: 332ms	remaining: 179ms
# 650:	learn: 0.3612486	total: 332ms	remaining: 178ms
# 651:	learn: 0.3612208	total: 333ms	remaining: 178ms
# 652:	learn: 0.3611877	total: 333ms	remaining: 177ms
# 653:	learn: 0.3611555	total: 334ms	remaining: 177ms
# 654:	learn: 0.3611238	total: 334ms	remaining: 176ms
# 655:	learn: 0.3610830	total: 335ms	remaining: 176ms
# 656:	learn: 0.3610554	total: 335ms	remaining: 175ms
# 657:	learn: 0.3610239	total: 336ms	remaining: 174ms
# 658:	learn: 0.3609846	total: 336ms	remaining: 174ms
# 659:	learn: 0.3608768	total: 337ms	remaining: 173ms
# 660:	learn: 0.3608162	total: 337ms	remaining: 173ms
# 661:	learn: 0.3607856	total: 338ms	remaining: 172ms
# 662:	learn: 0.3607357	total: 338ms	remaining: 172ms
# 663:	learn: 0.3606306	total: 339ms	remaining: 171ms
# 664:	learn: 0.3605950	total: 339ms	remaining: 171ms
# 665:	learn: 0.3604984	total: 340ms	remaining: 170ms
# 666:	learn: 0.3604752	total: 340ms	remaining: 170ms
# 667:	learn: 0.3604340	total: 341ms	remaining: 169ms
# 668:	learn: 0.3603813	total: 341ms	remaining: 169ms
# 669:	learn: 0.3603093	total: 342ms	remaining: 168ms
# 670:	learn: 0.3602685	total: 343ms	remaining: 168ms
# 671:	learn: 0.3602287	total: 343ms	remaining: 167ms
# 672:	learn: 0.3601772	total: 344ms	remaining: 167ms
# 673:	learn: 0.3601460	total: 344ms	remaining: 166ms
# 674:	learn: 0.3601059	total: 345ms	remaining: 166ms
# 675:	learn: 0.3600626	total: 345ms	remaining: 165ms
# 676:	learn: 0.3600370	total: 346ms	remaining: 165ms
# 677:	learn: 0.3600063	total: 346ms	remaining: 164ms
# 678:	learn: 0.3599670	total: 347ms	remaining: 164ms
# 679:	learn: 0.3599440	total: 347ms	remaining: 163ms
# 680:	learn: 0.3599045	total: 348ms	remaining: 163ms
# 681:	learn: 0.3598656	total: 348ms	remaining: 162ms
# 682:	learn: 0.3598304	total: 349ms	remaining: 162ms
# 683:	learn: 0.3598054	total: 349ms	remaining: 161ms
# 684:	learn: 0.3597758	total: 349ms	remaining: 161ms
# 685:	learn: 0.3597378	total: 350ms	remaining: 160ms
# 686:	learn: 0.3596996	total: 350ms	remaining: 160ms
# 687:	learn: 0.3596708	total: 351ms	remaining: 159ms
# 688:	learn: 0.3595631	total: 351ms	remaining: 159ms
# 689:	learn: 0.3595343	total: 352ms	remaining: 158ms
# 690:	learn: 0.3594888	total: 352ms	remaining: 158ms
# 691:	learn: 0.3594640	total: 353ms	remaining: 157ms
# 692:	learn: 0.3594355	total: 353ms	remaining: 156ms
# 693:	learn: 0.3593578	total: 354ms	remaining: 156ms
# 694:	learn: 0.3593080	total: 354ms	remaining: 155ms
# 695:	learn: 0.3592731	total: 355ms	remaining: 155ms
# 696:	learn: 0.3592343	total: 355ms	remaining: 154ms
# 697:	learn: 0.3591996	total: 356ms	remaining: 154ms
# 698:	learn: 0.3591711	total: 356ms	remaining: 153ms
# 699:	learn: 0.3591334	total: 357ms	remaining: 153ms
# 700:	learn: 0.3590110	total: 357ms	remaining: 152ms
# 701:	learn: 0.3589122	total: 358ms	remaining: 152ms
# 702:	learn: 0.3588840	total: 358ms	remaining: 151ms
# 703:	learn: 0.3587971	total: 359ms	remaining: 151ms
# 704:	learn: 0.3587697	total: 359ms	remaining: 150ms
# 705:	learn: 0.3587457	total: 360ms	remaining: 150ms
# 706:	learn: 0.3587066	total: 360ms	remaining: 149ms
# 707:	learn: 0.3586740	total: 361ms	remaining: 149ms
# 708:	learn: 0.3585774	total: 361ms	remaining: 148ms
# 709:	learn: 0.3585427	total: 362ms	remaining: 148ms
# 710:	learn: 0.3584908	total: 362ms	remaining: 147ms
# 711:	learn: 0.3584523	total: 363ms	remaining: 147ms
# 712:	learn: 0.3584266	total: 363ms	remaining: 146ms
# 713:	learn: 0.3583635	total: 364ms	remaining: 146ms
# 714:	learn: 0.3583341	total: 364ms	remaining: 145ms
# 715:	learn: 0.3582953	total: 365ms	remaining: 145ms
# 716:	learn: 0.3582728	total: 365ms	remaining: 144ms
# 717:	learn: 0.3582341	total: 366ms	remaining: 144ms
# 718:	learn: 0.3581967	total: 366ms	remaining: 143ms
# 719:	learn: 0.3581696	total: 367ms	remaining: 143ms
# 720:	learn: 0.3580875	total: 367ms	remaining: 142ms
# 721:	learn: 0.3580497	total: 368ms	remaining: 142ms
# 722:	learn: 0.3580066	total: 368ms	remaining: 141ms
# 723:	learn: 0.3579695	total: 369ms	remaining: 141ms
# 724:	learn: 0.3579322	total: 369ms	remaining: 140ms
# 725:	learn: 0.3578531	total: 370ms	remaining: 140ms
# 726:	learn: 0.3578163	total: 370ms	remaining: 139ms
# 727:	learn: 0.3577867	total: 371ms	remaining: 139ms
# 728:	learn: 0.3577506	total: 371ms	remaining: 138ms
# 729:	learn: 0.3577146	total: 372ms	remaining: 137ms
# 730:	learn: 0.3576792	total: 372ms	remaining: 137ms
# 731:	learn: 0.3576503	total: 373ms	remaining: 136ms
# 732:	learn: 0.3575868	total: 373ms	remaining: 136ms
# 733:	learn: 0.3575627	total: 374ms	remaining: 135ms
# 734:	learn: 0.3575297	total: 374ms	remaining: 135ms
# 735:	learn: 0.3575014	total: 375ms	remaining: 134ms
# 736:	learn: 0.3574481	total: 375ms	remaining: 134ms
# 737:	learn: 0.3573948	total: 376ms	remaining: 133ms
# 738:	learn: 0.3573749	total: 376ms	remaining: 133ms
# 739:	learn: 0.3573423	total: 377ms	remaining: 132ms
# 740:	learn: 0.3573081	total: 377ms	remaining: 132ms
# 741:	learn: 0.3572821	total: 378ms	remaining: 131ms
# 742:	learn: 0.3572483	total: 378ms	remaining: 131ms
# 743:	learn: 0.3572042	total: 379ms	remaining: 130ms
# 744:	learn: 0.3571707	total: 379ms	remaining: 130ms
# 745:	learn: 0.3571380	total: 380ms	remaining: 129ms
# 746:	learn: 0.3571051	total: 380ms	remaining: 129ms
# 747:	learn: 0.3570742	total: 381ms	remaining: 128ms
# 748:	learn: 0.3570424	total: 381ms	remaining: 128ms
# 749:	learn: 0.3570024	total: 382ms	remaining: 127ms
# 750:	learn: 0.3569552	total: 383ms	remaining: 127ms
# 751:	learn: 0.3569249	total: 383ms	remaining: 126ms
# 752:	learn: 0.3568872	total: 384ms	remaining: 126ms
# 753:	learn: 0.3568005	total: 384ms	remaining: 125ms
# 754:	learn: 0.3567585	total: 385ms	remaining: 125ms
# 755:	learn: 0.3567204	total: 385ms	remaining: 124ms
# 756:	learn: 0.3565829	total: 386ms	remaining: 124ms
# 757:	learn: 0.3565570	total: 386ms	remaining: 123ms
# 758:	learn: 0.3565358	total: 387ms	remaining: 123ms
# 759:	learn: 0.3564612	total: 388ms	remaining: 122ms
# 760:	learn: 0.3564347	total: 388ms	remaining: 122ms
# 761:	learn: 0.3564014	total: 389ms	remaining: 121ms
# 762:	learn: 0.3563518	total: 389ms	remaining: 121ms
# 763:	learn: 0.3562753	total: 390ms	remaining: 120ms
# 764:	learn: 0.3562245	total: 390ms	remaining: 120ms
# 765:	learn: 0.3562017	total: 391ms	remaining: 119ms
# 766:	learn: 0.3561653	total: 391ms	remaining: 119ms
# 767:	learn: 0.3561381	total: 392ms	remaining: 118ms
# 768:	learn: 0.3561117	total: 392ms	remaining: 118ms
# 769:	learn: 0.3560775	total: 393ms	remaining: 117ms
# 770:	learn: 0.3560420	total: 393ms	remaining: 117ms
# 771:	learn: 0.3560117	total: 394ms	remaining: 116ms
# 772:	learn: 0.3559784	total: 394ms	remaining: 116ms
# 773:	learn: 0.3559293	total: 395ms	remaining: 115ms
# 774:	learn: 0.3558961	total: 395ms	remaining: 115ms
# 775:	learn: 0.3558251	total: 396ms	remaining: 114ms
# 776:	learn: 0.3557986	total: 396ms	remaining: 114ms
# 777:	learn: 0.3557780	total: 397ms	remaining: 113ms
# 778:	learn: 0.3555995	total: 397ms	remaining: 113ms
# 779:	learn: 0.3554853	total: 398ms	remaining: 112ms
# 780:	learn: 0.3554526	total: 398ms	remaining: 112ms
# 781:	learn: 0.3554261	total: 399ms	remaining: 111ms
# 782:	learn: 0.3554000	total: 399ms	remaining: 111ms
# 783:	learn: 0.3553665	total: 400ms	remaining: 110ms
# 784:	learn: 0.3553409	total: 400ms	remaining: 110ms
# 785:	learn: 0.3552872	total: 401ms	remaining: 109ms
# 786:	learn: 0.3552573	total: 401ms	remaining: 109ms
# 787:	learn: 0.3552352	total: 402ms	remaining: 108ms
# 788:	learn: 0.3551922	total: 402ms	remaining: 108ms
# 789:	learn: 0.3551705	total: 403ms	remaining: 107ms
# 790:	learn: 0.3551387	total: 403ms	remaining: 107ms
# 791:	learn: 0.3550950	total: 404ms	remaining: 106ms
# 792:	learn: 0.3550611	total: 404ms	remaining: 106ms
# 793:	learn: 0.3550380	total: 405ms	remaining: 105ms
# 794:	learn: 0.3550130	total: 405ms	remaining: 105ms
# 795:	learn: 0.3549821	total: 406ms	remaining: 104ms
# 796:	learn: 0.3549224	total: 406ms	remaining: 104ms
# 797:	learn: 0.3548876	total: 407ms	remaining: 103ms
# 798:	learn: 0.3548668	total: 408ms	remaining: 103ms
# 799:	learn: 0.3548472	total: 408ms	remaining: 102ms
# 800:	learn: 0.3548260	total: 409ms	remaining: 102ms
# 801:	learn: 0.3548024	total: 409ms	remaining: 101ms
# 802:	learn: 0.3547444	total: 410ms	remaining: 101ms
# 803:	learn: 0.3547291	total: 411ms	remaining: 100ms
# 804:	learn: 0.3546957	total: 412ms	remaining: 99.7ms
# 805:	learn: 0.3546725	total: 412ms	remaining: 99.2ms
# 806:	learn: 0.3546096	total: 413ms	remaining: 98.7ms
# 807:	learn: 0.3545764	total: 413ms	remaining: 98.2ms
# 808:	learn: 0.3545441	total: 414ms	remaining: 97.8ms
# 809:	learn: 0.3545127	total: 415ms	remaining: 97.3ms
# 810:	learn: 0.3544838	total: 415ms	remaining: 96.8ms
# 811:	learn: 0.3544617	total: 416ms	remaining: 96.3ms
# 812:	learn: 0.3544291	total: 417ms	remaining: 95.8ms
# 813:	learn: 0.3543978	total: 417ms	remaining: 95.4ms
# 814:	learn: 0.3543760	total: 418ms	remaining: 94.9ms
# 815:	learn: 0.3543414	total: 419ms	remaining: 94.4ms
# 816:	learn: 0.3543110	total: 419ms	remaining: 93.9ms
# 817:	learn: 0.3542792	total: 420ms	remaining: 93.4ms
# 818:	learn: 0.3542614	total: 420ms	remaining: 92.9ms
# 819:	learn: 0.3542400	total: 421ms	remaining: 92.4ms
# 820:	learn: 0.3542011	total: 422ms	remaining: 91.9ms
# 821:	learn: 0.3541291	total: 422ms	remaining: 91.4ms
# 822:	learn: 0.3540986	total: 423ms	remaining: 90.9ms
# 823:	learn: 0.3540524	total: 424ms	remaining: 90.5ms
# 824:	learn: 0.3538843	total: 424ms	remaining: 90ms
# 825:	learn: 0.3538549	total: 425ms	remaining: 89.5ms
# 826:	learn: 0.3538205	total: 426ms	remaining: 89.1ms
# 827:	learn: 0.3537862	total: 426ms	remaining: 88.6ms
# 828:	learn: 0.3537548	total: 427ms	remaining: 88.1ms
# 829:	learn: 0.3537253	total: 428ms	remaining: 87.6ms
# 830:	learn: 0.3536806	total: 428ms	remaining: 87.1ms
# 831:	learn: 0.3536526	total: 429ms	remaining: 86.6ms
# 832:	learn: 0.3536152	total: 430ms	remaining: 86.1ms
# 833:	learn: 0.3535913	total: 430ms	remaining: 85.6ms
# 834:	learn: 0.3535608	total: 431ms	remaining: 85.1ms
# 835:	learn: 0.3535307	total: 431ms	remaining: 84.6ms
# 836:	learn: 0.3535024	total: 432ms	remaining: 84.1ms
# 837:	learn: 0.3534716	total: 432ms	remaining: 83.6ms
# 838:	learn: 0.3534424	total: 433ms	remaining: 83.1ms
# 839:	learn: 0.3534153	total: 434ms	remaining: 82.6ms
# 840:	learn: 0.3533884	total: 434ms	remaining: 82.1ms
# 841:	learn: 0.3533605	total: 435ms	remaining: 81.6ms
# 842:	learn: 0.3533328	total: 435ms	remaining: 81.1ms
# 843:	learn: 0.3532866	total: 436ms	remaining: 80.6ms
# 844:	learn: 0.3532409	total: 437ms	remaining: 80.1ms
# 845:	learn: 0.3532148	total: 437ms	remaining: 79.6ms
# 846:	learn: 0.3531737	total: 438ms	remaining: 79.1ms
# 847:	learn: 0.3531456	total: 439ms	remaining: 78.6ms
# 848:	learn: 0.3531050	total: 439ms	remaining: 78.1ms
# 849:	learn: 0.3530651	total: 440ms	remaining: 77.6ms
# 850:	learn: 0.3529039	total: 441ms	remaining: 77.2ms
# 851:	learn: 0.3528730	total: 441ms	remaining: 76.7ms
# 852:	learn: 0.3528537	total: 442ms	remaining: 76.2ms
# 853:	learn: 0.3528234	total: 443ms	remaining: 75.7ms
# 854:	learn: 0.3527949	total: 443ms	remaining: 75.2ms
# 855:	learn: 0.3527590	total: 444ms	remaining: 74.7ms
# 856:	learn: 0.3527313	total: 445ms	remaining: 74.2ms
# 857:	learn: 0.3527040	total: 445ms	remaining: 73.7ms
# 858:	learn: 0.3526807	total: 446ms	remaining: 73.2ms
# 859:	learn: 0.3526537	total: 446ms	remaining: 72.7ms
# 860:	learn: 0.3526254	total: 447ms	remaining: 72.2ms
# 861:	learn: 0.3525995	total: 448ms	remaining: 71.6ms
# 862:	learn: 0.3525735	total: 448ms	remaining: 71.1ms
# 863:	learn: 0.3525511	total: 449ms	remaining: 70.6ms
# 864:	learn: 0.3525298	total: 449ms	remaining: 70.1ms
# 865:	learn: 0.3524343	total: 450ms	remaining: 69.6ms
# 866:	learn: 0.3524006	total: 450ms	remaining: 69.1ms
# 867:	learn: 0.3523743	total: 451ms	remaining: 68.5ms
# 868:	learn: 0.3523486	total: 451ms	remaining: 68ms
# 869:	learn: 0.3523236	total: 452ms	remaining: 67.5ms
# 870:	learn: 0.3522844	total: 452ms	remaining: 67ms
# 871:	learn: 0.3522462	total: 453ms	remaining: 66.5ms
# 872:	learn: 0.3522236	total: 453ms	remaining: 65.9ms
# 873:	learn: 0.3521853	total: 454ms	remaining: 65.4ms
# 874:	learn: 0.3521664	total: 454ms	remaining: 64.9ms
# 875:	learn: 0.3521327	total: 455ms	remaining: 64.4ms
# 876:	learn: 0.3520811	total: 455ms	remaining: 63.9ms
# 877:	learn: 0.3520443	total: 456ms	remaining: 63.3ms
# 878:	learn: 0.3520072	total: 456ms	remaining: 62.8ms
# 879:	learn: 0.3519684	total: 457ms	remaining: 62.3ms
# 880:	learn: 0.3519416	total: 457ms	remaining: 61.8ms
# 881:	learn: 0.3519210	total: 458ms	remaining: 61.3ms
# 882:	learn: 0.3518912	total: 458ms	remaining: 60.7ms
# 883:	learn: 0.3518557	total: 459ms	remaining: 60.2ms
# 884:	learn: 0.3518305	total: 460ms	remaining: 59.7ms
# 885:	learn: 0.3518118	total: 460ms	remaining: 59.2ms
# 886:	learn: 0.3517827	total: 460ms	remaining: 58.7ms
# 887:	learn: 0.3517453	total: 461ms	remaining: 58.2ms
# 888:	learn: 0.3517193	total: 462ms	remaining: 57.6ms
# 889:	learn: 0.3516991	total: 462ms	remaining: 57.1ms
# 890:	learn: 0.3516734	total: 463ms	remaining: 56.6ms
# 891:	learn: 0.3516354	total: 463ms	remaining: 56.1ms
# 892:	learn: 0.3516106	total: 464ms	remaining: 55.6ms
# 893:	learn: 0.3515755	total: 464ms	remaining: 55ms
# 894:	learn: 0.3515449	total: 465ms	remaining: 54.5ms
# 895:	learn: 0.3515118	total: 465ms	remaining: 54ms
# 896:	learn: 0.3514870	total: 466ms	remaining: 53.5ms
# 897:	learn: 0.3514647	total: 466ms	remaining: 53ms
# 898:	learn: 0.3514383	total: 467ms	remaining: 52.4ms
# 899:	learn: 0.3514097	total: 467ms	remaining: 51.9ms
# 900:	learn: 0.3513914	total: 468ms	remaining: 51.4ms
# 901:	learn: 0.3513658	total: 468ms	remaining: 50.9ms
# 902:	learn: 0.3513308	total: 469ms	remaining: 50.4ms
# 903:	learn: 0.3513092	total: 469ms	remaining: 49.8ms
# 904:	learn: 0.3512772	total: 470ms	remaining: 49.3ms
# 905:	learn: 0.3512554	total: 470ms	remaining: 48.8ms
# 906:	learn: 0.3512296	total: 471ms	remaining: 48.3ms
# 907:	learn: 0.3512049	total: 471ms	remaining: 47.7ms
# 908:	learn: 0.3511811	total: 472ms	remaining: 47.2ms
# 909:	learn: 0.3511563	total: 472ms	remaining: 46.7ms
# 910:	learn: 0.3511321	total: 472ms	remaining: 46.2ms
# 911:	learn: 0.3510965	total: 473ms	remaining: 45.6ms
# 912:	learn: 0.3510749	total: 473ms	remaining: 45.1ms
# 913:	learn: 0.3510511	total: 474ms	remaining: 44.6ms
# 914:	learn: 0.3510261	total: 474ms	remaining: 44.1ms
# 915:	learn: 0.3509979	total: 475ms	remaining: 43.5ms
# 916:	learn: 0.3508464	total: 475ms	remaining: 43ms
# 917:	learn: 0.3508225	total: 476ms	remaining: 42.5ms
# 918:	learn: 0.3507975	total: 477ms	remaining: 42ms
# 919:	learn: 0.3507740	total: 477ms	remaining: 41.5ms
# ...
# 737:	learn: 0.2060551	total: 901ms	remaining: 320ms
# 738:	learn: 0.2059290	total: 902ms	remaining: 319ms
# 739:	learn: 0.2058481	total: 903ms	remaining: 317ms
# 740:	learn: 0.2055596	total: 905ms	remaining: 316ms
# 741:	learn: 0.2052989	total: 906ms	remaining: 315ms
# 742:	learn: 0.2052529	total: 907ms	remaining: 314ms
# 743:	learn: 0.2052013	total: 908ms	remaining: 312ms
# 744:	learn: 0.2050559	total: 909ms	remaining: 311ms
# 745:	learn: 0.2049292	total: 911ms	remaining: 310ms
# 746:	learn: 0.2048413	total: 912ms	remaining: 309ms
# 747:	learn: 0.2046729	total: 913ms	remaining: 308ms
# 748:	learn: 0.2045501	total: 914ms	remaining: 306ms
# 749:	learn: 0.2044733	total: 915ms	remaining: 305ms
# 750:	learn: 0.2044073	total: 917ms	remaining: 304ms
# 751:	learn: 0.2043632	total: 918ms	remaining: 303ms
# 752:	learn: 0.2042776	total: 919ms	remaining: 301ms
# 753:	learn: 0.2042498	total: 920ms	remaining: 300ms
# 754:	learn: 0.2042066	total: 921ms	remaining: 299ms
# 755:	learn: 0.2039596	total: 923ms	remaining: 298ms
# 756:	learn: 0.2036772	total: 924ms	remaining: 297ms
# 757:	learn: 0.2036175	total: 925ms	remaining: 295ms
# 758:	learn: 0.2035776	total: 926ms	remaining: 294ms
# 759:	learn: 0.2035299	total: 928ms	remaining: 293ms
# 760:	learn: 0.2034649	total: 929ms	remaining: 292ms
# 761:	learn: 0.2033232	total: 930ms	remaining: 290ms
# 762:	learn: 0.2030385	total: 931ms	remaining: 289ms
# 763:	learn: 0.2029974	total: 933ms	remaining: 288ms
# 764:	learn: 0.2028637	total: 934ms	remaining: 287ms
# 765:	learn: 0.2027740	total: 935ms	remaining: 286ms
# 766:	learn: 0.2027374	total: 936ms	remaining: 284ms
# 767:	learn: 0.2026435	total: 938ms	remaining: 283ms
# 768:	learn: 0.2025096	total: 939ms	remaining: 282ms
# 769:	learn: 0.2024342	total: 940ms	remaining: 281ms
# 770:	learn: 0.2023974	total: 941ms	remaining: 280ms
# 771:	learn: 0.2022265	total: 943ms	remaining: 278ms
# 772:	learn: 0.2021871	total: 944ms	remaining: 277ms
# 773:	learn: 0.2020786	total: 945ms	remaining: 276ms
# 774:	learn: 0.2020222	total: 946ms	remaining: 275ms
# 775:	learn: 0.2019876	total: 948ms	remaining: 274ms
# 776:	learn: 0.2019457	total: 949ms	remaining: 272ms
# 777:	learn: 0.2019153	total: 950ms	remaining: 271ms
# 778:	learn: 0.2018432	total: 952ms	remaining: 270ms
# 779:	learn: 0.2017325	total: 953ms	remaining: 269ms
# 780:	learn: 0.2015153	total: 954ms	remaining: 268ms
# 781:	learn: 0.2013154	total: 956ms	remaining: 266ms
# 782:	learn: 0.2012676	total: 957ms	remaining: 265ms
# 783:	learn: 0.2008082	total: 958ms	remaining: 264ms
# 784:	learn: 0.2007568	total: 959ms	remaining: 263ms
# 785:	learn: 0.2004612	total: 961ms	remaining: 262ms
# 786:	learn: 0.2002931	total: 962ms	remaining: 260ms
# 787:	learn: 0.2001518	total: 963ms	remaining: 259ms
# 788:	learn: 0.2000487	total: 964ms	remaining: 258ms
# 789:	learn: 0.2000112	total: 966ms	remaining: 257ms
# 790:	learn: 0.1998376	total: 967ms	remaining: 255ms
# 791:	learn: 0.1998060	total: 968ms	remaining: 254ms
# 792:	learn: 0.1994346	total: 969ms	remaining: 253ms
# 793:	learn: 0.1993150	total: 970ms	remaining: 252ms
# 794:	learn: 0.1992792	total: 971ms	remaining: 251ms
# 795:	learn: 0.1990620	total: 973ms	remaining: 249ms
# 796:	learn: 0.1989895	total: 974ms	remaining: 248ms
# 797:	learn: 0.1989027	total: 975ms	remaining: 247ms
# 798:	learn: 0.1988026	total: 976ms	remaining: 246ms
# 799:	learn: 0.1987722	total: 978ms	remaining: 244ms
# 800:	learn: 0.1986586	total: 979ms	remaining: 243ms
# 801:	learn: 0.1984310	total: 980ms	remaining: 242ms
# 802:	learn: 0.1982844	total: 982ms	remaining: 241ms
# 803:	learn: 0.1981995	total: 983ms	remaining: 240ms
# 804:	learn: 0.1980600	total: 985ms	remaining: 239ms
# 805:	learn: 0.1979130	total: 986ms	remaining: 237ms
# 806:	learn: 0.1978710	total: 987ms	remaining: 236ms
# 807:	learn: 0.1977897	total: 988ms	remaining: 235ms
# 808:	learn: 0.1976744	total: 990ms	remaining: 234ms
# 809:	learn: 0.1975388	total: 991ms	remaining: 232ms
# 810:	learn: 0.1975015	total: 992ms	remaining: 231ms
# 811:	learn: 0.1974088	total: 993ms	remaining: 230ms
# 812:	learn: 0.1972711	total: 995ms	remaining: 229ms
# 813:	learn: 0.1971276	total: 996ms	remaining: 228ms
# 814:	learn: 0.1967140	total: 997ms	remaining: 226ms
# 815:	learn: 0.1965168	total: 998ms	remaining: 225ms
# 816:	learn: 0.1964881	total: 1000ms	remaining: 224ms
# 817:	learn: 0.1964428	total: 1s	remaining: 223ms
# 818:	learn: 0.1963846	total: 1s	remaining: 221ms
# 819:	learn: 0.1961857	total: 1s	remaining: 220ms
# 820:	learn: 0.1960511	total: 1s	remaining: 219ms
# 821:	learn: 0.1960110	total: 1.01s	remaining: 218ms
# 822:	learn: 0.1958425	total: 1.01s	remaining: 217ms
# 823:	learn: 0.1957993	total: 1.01s	remaining: 215ms
# 824:	learn: 0.1956496	total: 1.01s	remaining: 214ms
# 825:	learn: 0.1954942	total: 1.01s	remaining: 213ms
# 826:	learn: 0.1954544	total: 1.01s	remaining: 212ms
# 827:	learn: 0.1951133	total: 1.01s	remaining: 211ms
# 828:	learn: 0.1950064	total: 1.01s	remaining: 209ms
# 829:	learn: 0.1948839	total: 1.02s	remaining: 208ms
# 830:	learn: 0.1948268	total: 1.02s	remaining: 207ms
# 831:	learn: 0.1946937	total: 1.02s	remaining: 206ms
# 832:	learn: 0.1944865	total: 1.02s	remaining: 205ms
# 833:	learn: 0.1943128	total: 1.02s	remaining: 204ms
# 834:	learn: 0.1941766	total: 1.02s	remaining: 202ms
# 835:	learn: 0.1940430	total: 1.02s	remaining: 201ms
# 836:	learn: 0.1939173	total: 1.03s	remaining: 200ms
# 837:	learn: 0.1938565	total: 1.03s	remaining: 199ms
# 838:	learn: 0.1937542	total: 1.03s	remaining: 197ms
# 839:	learn: 0.1935588	total: 1.03s	remaining: 196ms
# 840:	learn: 0.1932458	total: 1.03s	remaining: 195ms
# 841:	learn: 0.1932133	total: 1.03s	remaining: 194ms
# 842:	learn: 0.1931768	total: 1.03s	remaining: 193ms
# 843:	learn: 0.1931090	total: 1.03s	remaining: 191ms
# 844:	learn: 0.1929967	total: 1.04s	remaining: 190ms
# 845:	learn: 0.1929384	total: 1.04s	remaining: 189ms
# 846:	learn: 0.1926919	total: 1.04s	remaining: 188ms
# 847:	learn: 0.1925380	total: 1.04s	remaining: 187ms
# 848:	learn: 0.1925085	total: 1.04s	remaining: 185ms
# 849:	learn: 0.1924207	total: 1.04s	remaining: 184ms
# 850:	learn: 0.1923839	total: 1.04s	remaining: 183ms
# 851:	learn: 0.1922789	total: 1.05s	remaining: 182ms
# 852:	learn: 0.1921531	total: 1.05s	remaining: 181ms
# 853:	learn: 0.1919237	total: 1.05s	remaining: 179ms
# 854:	learn: 0.1918647	total: 1.05s	remaining: 178ms
# 855:	learn: 0.1917708	total: 1.05s	remaining: 177ms
# 856:	learn: 0.1917063	total: 1.05s	remaining: 176ms
# 857:	learn: 0.1915834	total: 1.05s	remaining: 174ms
# 858:	learn: 0.1914443	total: 1.05s	remaining: 173ms
# 859:	learn: 0.1913868	total: 1.06s	remaining: 172ms
# 860:	learn: 0.1912850	total: 1.06s	remaining: 171ms
# 861:	learn: 0.1911971	total: 1.06s	remaining: 170ms
# 862:	learn: 0.1911352	total: 1.06s	remaining: 168ms
# 863:	learn: 0.1910322	total: 1.06s	remaining: 167ms
# 864:	learn: 0.1908809	total: 1.06s	remaining: 166ms
# 865:	learn: 0.1905942	total: 1.06s	remaining: 165ms
# 866:	learn: 0.1904292	total: 1.06s	remaining: 163ms
# 867:	learn: 0.1903255	total: 1.07s	remaining: 162ms
# 868:	learn: 0.1901707	total: 1.07s	remaining: 161ms
# 869:	learn: 0.1899551	total: 1.07s	remaining: 160ms
# 870:	learn: 0.1898991	total: 1.07s	remaining: 159ms
# 871:	learn: 0.1896360	total: 1.07s	remaining: 157ms
# 872:	learn: 0.1895585	total: 1.07s	remaining: 156ms
# 873:	learn: 0.1895324	total: 1.07s	remaining: 155ms
# 874:	learn: 0.1894769	total: 1.08s	remaining: 154ms
# 875:	learn: 0.1894035	total: 1.08s	remaining: 152ms
# 876:	learn: 0.1892863	total: 1.08s	remaining: 151ms
# 877:	learn: 0.1891869	total: 1.08s	remaining: 150ms
# 878:	learn: 0.1891028	total: 1.08s	remaining: 149ms
# 879:	learn: 0.1890317	total: 1.08s	remaining: 148ms
# 880:	learn: 0.1887250	total: 1.08s	remaining: 146ms
# 881:	learn: 0.1886999	total: 1.08s	remaining: 145ms
# 882:	learn: 0.1886453	total: 1.09s	remaining: 144ms
# 883:	learn: 0.1886102	total: 1.09s	remaining: 143ms
# 884:	learn: 0.1884033	total: 1.09s	remaining: 142ms
# 885:	learn: 0.1883471	total: 1.09s	remaining: 140ms
# 886:	learn: 0.1883002	total: 1.09s	remaining: 139ms
# 887:	learn: 0.1881948	total: 1.09s	remaining: 138ms
# 888:	learn: 0.1879535	total: 1.09s	remaining: 137ms
# 889:	learn: 0.1879003	total: 1.09s	remaining: 135ms
# 890:	learn: 0.1878537	total: 1.1s	remaining: 134ms
# 891:	learn: 0.1876555	total: 1.1s	remaining: 133ms
# 892:	learn: 0.1876000	total: 1.1s	remaining: 132ms
# 893:	learn: 0.1875509	total: 1.1s	remaining: 131ms
# 894:	learn: 0.1875144	total: 1.1s	remaining: 129ms
# 895:	learn: 0.1874626	total: 1.1s	remaining: 128ms
# 896:	learn: 0.1873634	total: 1.1s	remaining: 127ms
# 897:	learn: 0.1873306	total: 1.11s	remaining: 126ms
# 898:	learn: 0.1872837	total: 1.11s	remaining: 124ms
# 899:	learn: 0.1870730	total: 1.11s	remaining: 123ms
# 900:	learn: 0.1870386	total: 1.11s	remaining: 122ms
# 901:	learn: 0.1868334	total: 1.11s	remaining: 121ms
# 902:	learn: 0.1867840	total: 1.11s	remaining: 119ms
# 903:	learn: 0.1866601	total: 1.11s	remaining: 118ms
# 904:	learn: 0.1866046	total: 1.11s	remaining: 117ms
# 905:	learn: 0.1863523	total: 1.12s	remaining: 116ms
# 906:	learn: 0.1863059	total: 1.12s	remaining: 115ms
# 907:	learn: 0.1862733	total: 1.12s	remaining: 113ms
# 908:	learn: 0.1861529	total: 1.12s	remaining: 112ms
# 909:	learn: 0.1861024	total: 1.12s	remaining: 111ms
# 910:	learn: 0.1858896	total: 1.12s	remaining: 110ms
# 911:	learn: 0.1858421	total: 1.12s	remaining: 109ms
# 912:	learn: 0.1857746	total: 1.13s	remaining: 107ms
# 913:	learn: 0.1857075	total: 1.13s	remaining: 106ms
# 914:	learn: 0.1856148	total: 1.13s	remaining: 105ms
# 915:	learn: 0.1855898	total: 1.13s	remaining: 104ms
# 916:	learn: 0.1854612	total: 1.13s	remaining: 102ms
# 917:	learn: 0.1854373	total: 1.13s	remaining: 101ms
# 918:	learn: 0.1853752	total: 1.13s	remaining: 99.9ms
# 919:	learn: 0.1853322	total: 1.14s	remaining: 98.7ms
# 920:	learn: 0.1852023	total: 1.14s	remaining: 97.5ms
# 921:	learn: 0.1850084	total: 1.14s	remaining: 96.3ms
# 922:	learn: 0.1848570	total: 1.14s	remaining: 95.1ms
# 923:	learn: 0.1847413	total: 1.14s	remaining: 93.8ms
# 924:	learn: 0.1846507	total: 1.14s	remaining: 92.6ms
# 925:	learn: 0.1844152	total: 1.14s	remaining: 91.4ms
# 926:	learn: 0.1842947	total: 1.14s	remaining: 90.2ms
# 927:	learn: 0.1841172	total: 1.15s	remaining: 88.9ms
# 928:	learn: 0.1838970	total: 1.15s	remaining: 87.7ms
# 929:	learn: 0.1838440	total: 1.15s	remaining: 86.5ms
# 930:	learn: 0.1837944	total: 1.15s	remaining: 85.3ms
# 931:	learn: 0.1837377	total: 1.15s	remaining: 84ms
# 932:	learn: 0.1837053	total: 1.15s	remaining: 82.8ms
# 933:	learn: 0.1836816	total: 1.15s	remaining: 81.6ms
# 934:	learn: 0.1836406	total: 1.16s	remaining: 80.3ms
# 935:	learn: 0.1835021	total: 1.16s	remaining: 79.1ms
# 936:	learn: 0.1833109	total: 1.16s	remaining: 77.9ms
# 937:	learn: 0.1831553	total: 1.16s	remaining: 76.7ms
# 938:	learn: 0.1830946	total: 1.16s	remaining: 75.4ms
# 939:	learn: 0.1830318	total: 1.16s	remaining: 74.2ms
# 940:	learn: 0.1828475	total: 1.16s	remaining: 73ms
# 941:	learn: 0.1827228	total: 1.17s	remaining: 71.7ms
# 942:	learn: 0.1824506	total: 1.17s	remaining: 70.5ms
# 943:	learn: 0.1824114	total: 1.17s	remaining: 69.3ms
# 944:	learn: 0.1823100	total: 1.17s	remaining: 68ms
# 945:	learn: 0.1822393	total: 1.17s	remaining: 66.8ms
# 946:	learn: 0.1820482	total: 1.17s	remaining: 65.6ms
# 947:	learn: 0.1818154	total: 1.17s	remaining: 64.4ms
# 948:	learn: 0.1817351	total: 1.18s	remaining: 63.2ms
# 949:	learn: 0.1816428	total: 1.18s	remaining: 61.9ms
# 950:	learn: 0.1815379	total: 1.18s	remaining: 60.7ms
# 951:	learn: 0.1814369	total: 1.18s	remaining: 59.4ms
# 952:	learn: 0.1811922	total: 1.18s	remaining: 58.2ms
# 953:	learn: 0.1810468	total: 1.18s	remaining: 57ms
# 954:	learn: 0.1809218	total: 1.18s	remaining: 55.7ms
# 955:	learn: 0.1808963	total: 1.18s	remaining: 54.5ms
# 956:	learn: 0.1806939	total: 1.19s	remaining: 53.3ms
# 957:	learn: 0.1805079	total: 1.19s	remaining: 52ms
# 958:	learn: 0.1802880	total: 1.19s	remaining: 50.8ms
# 959:	learn: 0.1801797	total: 1.19s	remaining: 49.6ms
# 960:	learn: 0.1801320	total: 1.19s	remaining: 48.3ms
# 961:	learn: 0.1800938	total: 1.19s	remaining: 47.1ms
# 962:	learn: 0.1800152	total: 1.19s	remaining: 45.8ms
# 963:	learn: 0.1799758	total: 1.19s	remaining: 44.6ms
# 964:	learn: 0.1798925	total: 1.2s	remaining: 43.3ms
# 965:	learn: 0.1798284	total: 1.2s	remaining: 42.1ms
# 966:	learn: 0.1796878	total: 1.2s	remaining: 40.9ms
# 967:	learn: 0.1796423	total: 1.2s	remaining: 39.6ms
# 968:	learn: 0.1794877	total: 1.2s	remaining: 38.4ms
# 969:	learn: 0.1793775	total: 1.2s	remaining: 37.2ms
# 970:	learn: 0.1793000	total: 1.2s	remaining: 35.9ms
# 971:	learn: 0.1791671	total: 1.2s	remaining: 34.7ms
# 972:	learn: 0.1790080	total: 1.21s	remaining: 33.4ms
# 973:	learn: 0.1789206	total: 1.21s	remaining: 32.2ms
# 974:	learn: 0.1788358	total: 1.21s	remaining: 31ms
# 975:	learn: 0.1787846	total: 1.21s	remaining: 29.7ms
# 976:	learn: 0.1786020	total: 1.21s	remaining: 28.5ms
# 977:	learn: 0.1785516	total: 1.21s	remaining: 27.2ms
# 978:	learn: 0.1784283	total: 1.21s	remaining: 26ms
# 979:	learn: 0.1782580	total: 1.21s	remaining: 24.8ms
# 980:	learn: 0.1782345	total: 1.22s	remaining: 23.5ms
# 981:	learn: 0.1782105	total: 1.22s	remaining: 22.3ms
# 982:	learn: 0.1780883	total: 1.22s	remaining: 21.1ms
# 983:	learn: 0.1780156	total: 1.22s	remaining: 19.8ms
# 984:	learn: 0.1778003	total: 1.22s	remaining: 18.6ms
# 985:	learn: 0.1777441	total: 1.22s	remaining: 17.3ms
# 986:	learn: 0.1775675	total: 1.22s	remaining: 16.1ms
# 987:	learn: 0.1775248	total: 1.22s	remaining: 14.9ms
# 988:	learn: 0.1774616	total: 1.23s	remaining: 13.6ms
# 989:	learn: 0.1773747	total: 1.23s	remaining: 12.4ms
# 990:	learn: 0.1772079	total: 1.23s	remaining: 11.2ms
# 991:	learn: 0.1770472	total: 1.23s	remaining: 9.91ms
# 992:	learn: 0.1770104	total: 1.23s	remaining: 8.67ms
# 993:	learn: 0.1768491	total: 1.23s	remaining: 7.43ms
# 994:	learn: 0.1768140	total: 1.23s	remaining: 6.2ms
# 995:	learn: 0.1767889	total: 1.23s	remaining: 4.96ms
# 996:	learn: 0.1767113	total: 1.24s	remaining: 3.72ms
# 997:	learn: 0.1765586	total: 1.24s	remaining: 2.48ms
# 998:	learn: 0.1765235	total: 1.24s	remaining: 1.24ms
# 999:	learn: 0.1763519	total: 1.24s	remaining: 0us
# GridSearchCV(cv=3, error_score='raise',
#              estimator=Pipeline(steps=[('scaler',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['monthly_charges',
#                                                                           'duration_time_days']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(),
#                                                                          ['senior_citizen',
#                                                                           'partner',
#                                                                           'dependents',
#                                                                           'type',
#                                                                           'paperless_billing',
#                                                                           'payment_method',
#                                                                           'online_security',
#                                                                           'online_backup',
#                                                                           'device_protection',
#                                                                           'tech_support',
#                                                                           '...
#                          {'model': [DecisionTreeClassifier(random_state=12)],
#                           'model__criterion': ['gini', 'entropy'],
#                           'model__max_depth': range(1, 6)},
#                          {'model': [RandomForestClassifier(random_state=12)],
#                           'model__max_depth': range(1, 6),
#                           'model__n_estimators': range(10, 101, 30)},
#                          {'model': [<catboost.core.CatBoostClassifier object at 0x7f86b6c3cfd0>],
#                           'model__depth': range(1, 6),
#                           'model__learning_rate': [0.01, 0.03, 0.001]}],
#              scoring='roc_auc')

# %% [markdown]
# Выведем лучшую модель.

# %%
get_results(grid_pipe, 'CatBoostClassifier')
# Out:
# Модель CatBoostClassifier:
# Параметры: {'model': <catboost.core.CatBoostClassifier object at 0x7f86b6c3cfd0>, 'model__depth': 5, 'model__learning_rate': 0.03}
# ROC-AUC: 0.896539501098553

# %% [markdown]
# **Вывод:**
#
# Видно, что лучше всех себя показала модель **CatBoostClassifier** с параметрами `{'depth': 5, 'learning_rate': 0.03}` и ROC-AUC: `0.90`.

# %% [markdown]
# ## Проверка модели

# %% [markdown]
# Проверим наилучшую модель на тестовой выборке.

# %%
model_best = cb.CatBoostClassifier(random_state=RANDOM_STATE, depth= 5,  learning_rate = 0.03, cat_features=ohe_features, verbose = False)
model_best.fit(features_train, target_train)

print(f'Acc: {accuracy_score(model_best.predict(features_test), target_test)}')
print(f'ROC-AUC: {roc_auc_score(target_test, model_best.predict_proba(features_test)[:, 1])}')
# Out:
# Acc: 0.9070262597586941
# ROC-AUC: 0.9196612890893799

# %% [markdown]
# Проанализируем матрицу ошибок.

# %%
def plot_conf_matr(model_best, f_test, t_test):
    predictions = model_best.predict(f_test)
    print(f'Количество записей: {t_test.shape[0]}\n')

    cf_matrix = confusion_matrix(predictions, t_test)

    ax = sns.heatmap(cf_matrix, annot= True , fmt="d",  cmap='Blues')

    ax.set_title('Confusion Matrix\n');
    ax.set_xlabel('\nPredicted Values')
    ax.set_ylabel('Actual Values ');


    ax.xaxis.set_ticklabels(['False','True'])
    ax.yaxis.set_ticklabels(['False','True'])

# %%
plot_conf_matr(model_best, features_test, target_test)
# Out:
# Количество записей: 1409

# %% [markdown]
# **Вывод:**
#
# * Значение `accuracy` и `roc-auc` на тестовой выборке: **0.90** и **0.89**
#
# Из построенной матрицы ошибок можно сделать вывод:
#
# * значение TrueNegative - 1409, т.е модель хорошо предсказывает пользователей, которые не уйдут.
# * значение TruePositive - 110, т.е модель хорошо предсказывает пользователей, которые на самом деле не уйдут. Правильных ответов - 110 из 131.
# * Значение False Positive - 21, т.е модель не так сильно промахивается в предсказании пользователей, которые уйдут. Неправильных ответов - 21 из 131.
# * значение FalseNegative - 110, т.е модель иногда предсказывает, что пользователи, которые не должны уйти, уйдут. Это не так страшно, ведь главная цель, как можно лучше определить пользоватлей, которые могут покинуть сервис.

# %% [markdown]
# ## Анализ важности признаков

# %%
def plot_features_importances(data):
    sns.barplot(x=data.sort_values(by=0).values.reshape((13,)),
                y=np.array(data.sort_values(by=0).index))

    plt.title('Feature importance')
    plt.ylabel('features')
    plt.xlabel('importance');

# %%
feature_importance_data = pd.DataFrame(model_best.feature_importances_,
                                       index=features_test.columns)

plot_features_importances(feature_importance_data)

# %% [markdown]
# **Вывод:**
#
# Из графика видно, что `тип оплаты`, `ежемесяячные траты на услуги по договру` и `срок пользования услугами в днях` — являются самыми значимыми.

# %% [markdown]
# **Вывод:**
#
# Подводя итоги, сделаем выводы по каждому пункту:
#
# 1. Загрузка и изучение данных.
#
# 2. Подготовка данных
#
# 3. Исследовательский анализ данных.
#
# 5. Предобработка данных.
#
# 6. Подготовка данных к обучению.
#
# 7. Обучение модели.
#
# 8. Проверка модели
#
# 9. Анализ важности признаков.
#
# 10. Вывод.
#
#
# **Обзор данных**
#
# * подключены все необходимые библиотеки
# * успешно загружены данные
# * получены общие данные о таблице
# * все столбцы приведены к нижнему регистру
# * изменены некорректные типы данных в столбцах
# * выявлены неявные пропуски
#
# **Подготовка данных**
#
# * соединены таблицы
# * добавлен целевой признак `is_clien`
# * добавлен новый признак `duration_time_days`
# * удалены незначащие столбцы
#
# **Исследовательский анализ данных**
#
# * построены распределения категориальных и количественных признаков
# * определены тенденции
#
# **Предобработка данныхх**
#
# * удалены пропуски и заполнены пропущенные значения
# * проведено исследование признаков на мультиколлинеарность
# * удалены сильно коррелирующие признаки
# * выявлен диссбаланс классов
#
# **Подготовка данных к обучению**
#
# * разделены данные на обучающую и тестовую выборки в соотношении 3:1
# * произведена кодировка данных с помщью OrdinalEncoder
# * признаки приведены к одному масштабу
#
# **Обучение модели**
#
# Были обучены следующие модели:
#
# Простые модели:
#
# * DecisionTreeClassifier
# * RandomForestClassifier
#
# Модели на основе градиентного бустинга:
#
# * CatBoostClassifier
#
# Лучше всех себя показала модель `CatBoostClassifier` с метрикой `roc-auc` - 0.90.
#
# **Проверка модели**
#
# Значение модели на тестовой выборке:
#
# * `Accuracy`: 0.90
# * `ROC-AUC`: 0.90
#
# Проведен анализ матрицы ошибок, который показал, что:
#
# * значение TrueNegative - 1469, т.е модель хорошо предсказывает пользователей, которые не уйдут.
# * значение TruePositive - 122, т.е модель хорошо предсказывает пользователей, которые на самом деле не уйдут. Правильных ответов - 122 из 139.
# * Значение False Positive - 17, т.е модель не так сильно промахивается в предсказании пользователей, которые уйдут. Неправильных ответов - 17 из 139.
# * значение FalseNegative - 153, т.е модель иногда предсказывает, что пользователи, которые не должны уйти, уйдут. Это не так страшно, ведь главная цель, как можно лучше определить пользоватлей, которые могут покинуть сервис.
#
# **Анализ важности признаков**
#
# Выявлены самые значащие признаки:
#
# * `тип оплаты`
# * `ежемесяячные траты на услуги по договру`
# * `срок пользования услугами в днях`

# %% [markdown]
# ## Отчет

# %% [markdown]
# **Выделим ключевые шаги работы над проектом:**
#
# 1. Загрузка и изучение данных.
#
# 2. Подготовка данных
#
# 3. Исследовательский анализ данных.
#
# 4. Предобработка данных.
#
# 5. Подготовка данных к обучению.
#
# 6. Обучение модели.
#
# 7. Проверка модели.
#
# 8. Анализ важности признаков.
#
# **Проанализируем соответствие фактической работы запланированным шагам:**
#
# Данные были успешно:
#
#     1. Загружены и изучены.
#     2. Подготовлены к работе и исследованию.
#     3. Исследованы наглядным образом.
#     4. Предобработаны.
#     5. Подготовленны к обучению.
#
# Модели были успешно:
#
#     1. Обучены с разными гиперпараметрами.
#     2. Проанализированы на лучшее качество предсказаний.
#
# Лучшая модель была успешно:
#
#     1. Проверенная на тестовой выборке.
#     2. Проранжированна по важности признаков.
#
#
# **Рефлексия над сложностями и описание путей их решения:**
#
# 1. На этапе загрузки и изучения данных были следующие проблемы:
#     * При попытке изменить тип данных в столбце `totalcharges` были найдены неявные пропуски, а точнее пустые строки, что не давало привести столбец к типу `float`. Следовательно, было принято решение использовать функцию `to_numeric` библиотеки *pandas* с параметром `errors = 'coerce'`, чтобы вместо шибки возвращалось значение Nan.
#
# 2. На этапе подготовки данных были следующие проблемы:
#     * В данных отсутствовал целевой признак `клиент ушел? — да или нет`. Следовательно, было принято решение создать целевой признак с помощью столбца `end_date`, то есть  если дата имеет значения `2020-02-01` (дата выгрузки данных), то клиент не ушел, а если другая дата, то клиент покинул сервис. Изначально в столбце `end_date` были даты ухода и значения `No`, поэтому было принято решение заменить значения `No` — датой выгрузки (`2020-02-01`).
#
# 3. На этапе исследования данных проблем не было.
#
# 4. На этапе предобработки данных проблем не было.
#
# 5. На этапе подготовки данных к обучению были следующие проблем:
#
#     * Необходимо было выбрать метод кодирования категориальных признаков. Для древесных и бустинговых моделей лучше всего подходит метод кодирования `OrdinalEncoder()`, так как он не создает дополнительных столбцов, поэтому было принято решение использовать его.
#
# 6. На этапе обучения модели проблем не было.
# 7. На этапе проверки модели проблем не было.
# 8. На этапе анализа важности признаков проблем не было.
#
# **Итоговый список признаков для обучения и способы обработки:**
#
# Итоговый список признаков:
#
# * `senior_citizen` — наличие пенсионного статуса по возрасту,
# * `partner` — наличие супруга(и),
# * `dependents` — наличие иждивенцев,
# * `type` — тип оплаты: ежемесячный, годовой и тд,
# * `paperless_billing` — безбумажное выставление счета,
# * `payment_method` — способ оплаты,
# * `monthly_charges` — ежемесячные траты на услуги по договору,
# * `online_security` — онлайн-безопасность
# * `online_backup` — онлайн резервное копирование
# * `device_protection` — защита устройства,
# * `tech_support` — техническая поддержка
# * `multiple_lines` — наличие возможности ведения параллельных линий во время звонка
# * `duration_time_days` — срок пользования услугами в днях.
#
# Целевой признак:
#
# * `is_client` - остался ли клиент в сервисе.
#
#
# Кодирование категориальны признаков производилось с помощью `OrdinalEncoder()`.
#
# Стандартизация количественных признаков производилось с помощью `StandardScaler()`.
#
# **Краткое описание предобработки данных:**
#
# На этапе предобработки были выявлены следующие проблемы в данных:
#
# 1. Присутсвуют пропуски в столбцах:
#
# * `online_security`
# * `online_backup`
# * `streaming_movies`
# * `streaming_t_`
# * `tech_support`
# * `internet_service`
# * `device_protection`
# * `multiple_lines`
# * `total_charges`
#
# 2. Присутствует мультиколлинеарность:
#
# * столбцы `internet_service`,  `streaming_t_v`, `streaming_movies` сильно коррелируют с признаком `monthly_charges`,
# * столбец `total_charges` сильно коррелирует со столбцом `duration_time_days`,
# * присутствует дисбаланс классов целевого признака `is_client`.
#
# Были приняты следующие решения:
#
# 1.
# * Пропуски в первых 9-и столбцах говорят о том, что, либо данные некоторых клиентов не внесены в базу, либо у клиента попросту нет данных функций. Следовательно, было приянто решение заполнить пропуски отрицательными значениями,
#
# * Пропусков в значениях столбца `total_charges` говорят о том, что пользователь еще не успел совершить покупки, поэтому было принято решение заполнить значением `0`.
#
# 2.
# * так как столбцы `internet_service`,  `streaming_t_v`, `streaming_movies` сильно коррелируют с признаком `monthly_charges`, было принято решение удалить их,
#
# * так как столбец `total_charges` сильно коррелирует со столбцом `duration_time_days`, было принято удалить столбец `total_charges`,
#
# 3.
# * так как при обучении была выбрана метрика качества `ROC-AUC`, которая нечувствительна к дисбалансу классов, было принято решение не производить никаких манипуляций с целевой переменной.
#
# **Сводная таблица исследованных моделей и их метрика на кросс-валидации:**
#
# | **Модель**            | **ROC-AUC**   |
# | --------------------- |:-------------:|
# | DecisionTreeClassifier| 0.79 |
# | RandomForestClassifier| 0.82 |
# | CatBoostClassifier    | 0.90 |
#
# **Лучшая модель:**
#
# | **Модель**            | **Гиперпараметры**   | **ROC-AUC**   |
# | --------------------- |:--------------------:|:-------------:|
# | CatBoostClassifier    | 'depth': 5, 'learning_rate': 0.03 | 0.90
#
# **Итоговые метрики лучшей модели на test:**
#
# | **Модель**            | **Accuracy**   | **ROC-AUC**   |
# | --------------------- |:--------------------:|:-------------:|
# | CatBoostClassifier    | 0.90 | 0.89
#
# **Матрица ошибок**

# %%
plot_conf_matr(model_best, features_test, target_test)
# Out:
# Количество записей: 1409

# %% [markdown]
# Из построенной матрицы ошибок можно сделать вывод:
#
# * значение TrueNegative - 1469, т.е модель хорошо предсказывает пользователей, которые не уйдут.
# * значение TruePositive - 122, т.е модель хорошо предсказывает пользователей, которые на самом деле не уйдут. Правильных ответов - 122 из 139.
# * Значение False Positive - 17, т.е модель не так сильно промахивается в предсказании пользователей, которые уйдут. Неправильных ответов - 17 из 139.
# * значение FalseNegative - 153, т.е модель иногда предсказывает, что пользователи, которые не должны уйти, уйдут. Это не так страшно, ведь главная цель, как можно лучше определить пользоватлей, которые могут покинуть сервис.
#
# **Важность признаков:**

# %%
plot_features_importances(feature_importance_data)

# %% [markdown]
# Из графика видно, что `тип оплаты`, `ежемесяячные траты на услуги по договру` и `срок пользования услугами в днях` — являются самыми значимыми.
